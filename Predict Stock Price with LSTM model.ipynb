# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

# %%
df=pd.read_csv("AAPL.csv",parse_dates=["Date"],index_col=[0])
print(df.index.freq)
missing_dates = pd.date_range(start=df.index.min(), end=df.index.max()).difference(df.index)
print(missing_dates)
df.shape
# Out:
# None
# DatetimeIndex(['2022-07-02', '2022-07-03', '2022-07-04', '2022-07-09',
#                '2022-07-10', '2022-07-16', '2022-07-17', '2022-07-23',
#                '2022-07-24', '2022-07-30',
#                ...
#                '2023-05-29', '2023-06-03', '2023-06-04', '2023-06-10',
#                '2023-06-11', '2023-06-17', '2023-06-18', '2023-06-19',
#                '2023-06-24', '2023-06-25'],
#               dtype='datetime64[ns]', length=114, freq=None)
# (251, 6)

# %%
# Dropping the specified columns
df.drop(columns=["Open", "Close", "Adj Close", "Volume"], inplace=True)

# Calculate the midpoint of low and high and save it as 'Mid'
df["Mid"] = (df["Low"] + df["High"]) / 2
df.to_csv('apple.csv')
df.head()
# Out:
#                   High         Low         Mid
# Date
# 2022-07-01  139.039993  135.660004  137.349998
# 2022-07-05  141.610001  136.929993  139.269997
# 2022-07-06  144.119995  141.080002  142.599998
# 2022-07-07  146.550003  143.279999  144.915001
# 2022-07-08  147.550003  145.000000  146.275002

# %%
def train_test_split(data, prediction_size):
    train_size = int(len(data) * (1-prediction_size))
    train = pd.DataFrame(data[0:train_size])
    test = pd.DataFrame(data[train_size:len(data)])
    return train, test
df_train, df_test = train_test_split(df, 0.2)

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (200, 3)
# (51, 3)

# %%
# 归一化
scaler = MinMaxScaler(feature_range=(0,1))
df_train_scaled = scaler.fit_transform(df_train)
df_test_scaled = scaler.transform(df_test)

# %%
len(df_test_scaled)
# Out:
# 51

# %%
def generate_time_series_data(input_data, history_length):
    X_data, Y_data = [], []

    for idx in range(history_length, len(input_data)):
        X_data.append(input_data[idx-history_length :idx, 0:input_data.shape[1]])
#         Y_data.append(input_data[idx, 0:input_data.shape[1]]) #这是沿第二个维度（特征）的切片，从第一个特征开始，到最后一个特征结束。简而言之，我们选择了所有的特征。
        Y_data.append(input_data[idx, 0])
    return np.array(X_data), np.array(Y_data)

# %%
df_train.shape[1]
# Out:
# 3

# %%
trainX,trainY=generate_time_series_data(df_train_scaled,5)
testX,testY=generate_time_series_data(df_test_scaled,5)
print("trainX Shape-- ",trainX.shape) #trainX consists of 1984 time Windows, each consisting of 30 consecutive time steps with 6 features per time step
print("trainY Shape-- ",trainY.shape)
print("testX Shape-- ",testX.shape)
print("testY Shape-- ",testY.shape)
print("trainX[0]-- \n",trainX[0])
print("\ntrainY[0]-- ",trainY[0])
# Out:
# trainX Shape--  (195, 5, 3)
# trainY Shape--  (195,)
# testX Shape--  (46, 5, 3)
# testY Shape--  (46,)
# trainX[0]--
#  [[0.23294743 0.23472945 0.23048131]
#  [0.28606872 0.26067407 0.27040227]
#  [0.33794955 0.34545465 0.33964027]
#  [0.38817708 0.39039841 0.38777422]
#  [0.40884678 0.42553633 0.4160516 ]]
#
# trainY[0]--  0.390037270982055

# %%
def build_model(optimizer):
    grid_model = Sequential()
    grid_model.add(LSTM(50,return_sequences=True,input_shape=(5,3), activation='relu'))
    grid_model.add(Dropout(0.2))
    grid_model.add(LSTM(units=50, activation='relu'))
    grid_model.add(Dense(units=1))

    grid_model.compile(loss = 'mse',optimizer = optimizer)
    return grid_model

grid_model = KerasRegressor(build_fn=build_model,verbose=1,validation_data=(testX,testY))
parameters = {'batch_size' : [8, 16, 32],
              'epochs' : [5, 10, 20],
              'optimizer' : ['adam','Adadelta'] }

grid_search  = GridSearchCV(estimator = grid_model,
                            param_grid = parameters,
                            cv = 2)
# Out:
# C:\Users\eq220\AppData\Local\Temp\ipykernel_44472\3441814425.py:11: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   grid_model = KerasRegressor(build_fn=build_model,verbose=1,validation_data=(testX,testY))

# %%
grid_search = grid_search.fit(trainX,trainY)
# Out:
# Epoch 1/5
# 13/13 [==============================] - 1s 20ms/step - loss: 0.1991 - val_loss: 0.7371
# Epoch 2/5
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0819 - val_loss: 0.0521
# Epoch 3/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0179 - val_loss: 0.0064
# Epoch 4/5
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0138 - val_loss: 0.0190
# Epoch 5/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0096 - val_loss: 0.0051
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0088
# Epoch 1/5
# 13/13 [==============================] - 1s 18ms/step - loss: 0.2336 - val_loss: 0.3358
# Epoch 2/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0416 - val_loss: 0.0315
# Epoch 3/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0172 - val_loss: 0.0580
# Epoch 4/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0148 - val_loss: 0.0096
# Epoch 5/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0116 - val_loss: 0.0116
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0108
# Epoch 1/5
# 13/13 [==============================] - 1s 18ms/step - loss: 0.2352 - val_loss: 1.1115
# Epoch 2/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2344 - val_loss: 1.1106
# Epoch 3/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2343 - val_loss: 1.1097
# Epoch 4/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2338 - val_loss: 1.1089
# Epoch 5/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2340 - val_loss: 1.1080
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3470
# Epoch 1/5
# 13/13 [==============================] - 1s 17ms/step - loss: 0.3422 - val_loss: 1.1036
# Epoch 2/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3415 - val_loss: 1.1031
# Epoch 3/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3425 - val_loss: 1.1026
# Epoch 4/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3412 - val_loss: 1.1021
# Epoch 5/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3416 - val_loss: 1.1015
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2328
# Epoch 1/10
# 13/13 [==============================] - 1s 17ms/step - loss: 0.1886 - val_loss: 0.6660
# Epoch 2/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0699 - val_loss: 0.0285
# Epoch 3/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0174 - val_loss: 0.0035
# Epoch 4/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0269
# Epoch 5/10
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0099 - val_loss: 0.0041
# Epoch 6/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0092 - val_loss: 0.0059
# Epoch 7/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.0200
# Epoch 8/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0073 - val_loss: 0.0197
# Epoch 9/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0073 - val_loss: 0.0516
# Epoch 10/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.0086
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 1/10
# 13/13 [==============================] - 1s 32ms/step - loss: 0.2558 - val_loss: 0.5218
# Epoch 2/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0619 - val_loss: 0.0405
# Epoch 3/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0203 - val_loss: 0.0125
# Epoch 4/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0168 - val_loss: 0.0198
# Epoch 5/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0027
# Epoch 6/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0117 - val_loss: 0.0162
# Epoch 7/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0130 - val_loss: 0.0036
# Epoch 8/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0106 - val_loss: 0.0124
# Epoch 9/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0034
# Epoch 10/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0113 - val_loss: 0.0092
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 1/10
# 13/13 [==============================] - 1s 17ms/step - loss: 0.2294 - val_loss: 1.0866
# Epoch 2/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2301 - val_loss: 1.0860
# Epoch 3/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2289 - val_loss: 1.0854
# Epoch 4/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2292 - val_loss: 1.0847
# Epoch 5/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2294 - val_loss: 1.0841
# Epoch 6/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2283 - val_loss: 1.0834
# Epoch 7/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2279 - val_loss: 1.0828
# Epoch 8/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2281 - val_loss: 1.0820
# Epoch 9/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2279 - val_loss: 1.0813
# Epoch 10/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2285 - val_loss: 1.0807
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3367
# Epoch 1/10
# 13/13 [==============================] - 1s 18ms/step - loss: 0.3640 - val_loss: 1.1679
# Epoch 2/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3627 - val_loss: 1.1673
# Epoch 3/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3638 - val_loss: 1.1666
# Epoch 4/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3617 - val_loss: 1.1660
# Epoch 5/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3616 - val_loss: 1.1653
# Epoch 6/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3611 - val_loss: 1.1647
# Epoch 7/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3628 - val_loss: 1.1640
# Epoch 8/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3615 - val_loss: 1.1633
# Epoch 9/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3607 - val_loss: 1.1626
# Epoch 10/10
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3613 - val_loss: 1.1620
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2444
# Epoch 1/20
# 13/13 [==============================] - 1s 17ms/step - loss: 0.2031 - val_loss: 0.7283
# Epoch 2/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0951 - val_loss: 0.1035
# Epoch 3/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0200 - val_loss: 0.0668
# Epoch 4/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0111 - val_loss: 0.0247
# Epoch 5/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0115 - val_loss: 0.0105
# Epoch 6/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.0099
# Epoch 7/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0078 - val_loss: 0.0242
# Epoch 8/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0286
# Epoch 9/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0077 - val_loss: 0.0387
# Epoch 10/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0082 - val_loss: 0.0381
# Epoch 11/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0073 - val_loss: 0.0238
# Epoch 12/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.0304
# Epoch 13/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0299
# Epoch 14/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.0188
# Epoch 15/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0071 - val_loss: 0.0290
# Epoch 16/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0254
# Epoch 17/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 0.0140
# Epoch 18/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.0284
# Epoch 19/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.0057
# Epoch 20/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0066 - val_loss: 0.0095
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0085
# Epoch 1/20
# 13/13 [==============================] - 2s 18ms/step - loss: 0.2120 - val_loss: 0.3456
# Epoch 2/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0402 - val_loss: 0.0348
# Epoch 3/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0187 - val_loss: 0.0496
# Epoch 4/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0122 - val_loss: 0.0079
# Epoch 5/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0114 - val_loss: 0.0097
# Epoch 6/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0132
# Epoch 7/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0102 - val_loss: 0.0079
# Epoch 8/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0115
# Epoch 9/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0102 - val_loss: 0.0068
# Epoch 10/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0108
# Epoch 11/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0055
# Epoch 12/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0095 - val_loss: 0.0081
# Epoch 13/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0109 - val_loss: 0.0035
# Epoch 14/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0046
# Epoch 15/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0111 - val_loss: 0.0031
# Epoch 16/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0039
# Epoch 17/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0039
# Epoch 18/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0093 - val_loss: 0.0040
# Epoch 19/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0105 - val_loss: 0.0067
# Epoch 20/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0088 - val_loss: 0.0057
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0087
# Epoch 1/20
# 13/13 [==============================] - 1s 18ms/step - loss: 0.2016 - val_loss: 0.9521
# Epoch 2/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2016 - val_loss: 0.9512
# Epoch 3/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2001 - val_loss: 0.9503
# Epoch 4/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2008 - val_loss: 0.9493
# Epoch 5/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2006 - val_loss: 0.9484
# Epoch 6/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2013 - val_loss: 0.9474
# Epoch 7/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2007 - val_loss: 0.9465
# Epoch 8/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1995 - val_loss: 0.9456
# Epoch 9/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2009 - val_loss: 0.9447
# Epoch 10/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1994 - val_loss: 0.9437
# Epoch 11/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1992 - val_loss: 0.9427
# Epoch 12/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1981 - val_loss: 0.9417
# Epoch 13/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1995 - val_loss: 0.9408
# Epoch 14/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1986 - val_loss: 0.9398
# Epoch 15/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1995 - val_loss: 0.9388
# Epoch 16/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1975 - val_loss: 0.9378
# Epoch 17/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1977 - val_loss: 0.9368
# Epoch 18/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1973 - val_loss: 0.9358
# Epoch 19/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1980 - val_loss: 0.9347
# Epoch 20/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1979 - val_loss: 0.9337
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2911
# Epoch 1/20
# 13/13 [==============================] - 1s 18ms/step - loss: 0.3535 - val_loss: 1.1332
# Epoch 2/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3526 - val_loss: 1.1326
# Epoch 3/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3536 - val_loss: 1.1320
# Epoch 4/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3520 - val_loss: 1.1313
# Epoch 5/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3515 - val_loss: 1.1307
# Epoch 6/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3523 - val_loss: 1.1300
# Epoch 7/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3524 - val_loss: 1.1294
# Epoch 8/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3512 - val_loss: 1.1287
# Epoch 9/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3525 - val_loss: 1.1280
# Epoch 10/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3502 - val_loss: 1.1273
# Epoch 11/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3498 - val_loss: 1.1266
# Epoch 12/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3505 - val_loss: 1.1259
# Epoch 13/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3492 - val_loss: 1.1252
# Epoch 14/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3508 - val_loss: 1.1245
# Epoch 15/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3480 - val_loss: 1.1239
# Epoch 16/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3486 - val_loss: 1.1232
# Epoch 17/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3488 - val_loss: 1.1225
# Epoch 18/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3494 - val_loss: 1.1217
# Epoch 19/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3485 - val_loss: 1.1210
# Epoch 20/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3489 - val_loss: 1.1203
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2355
# Epoch 1/5
# 7/7 [==============================] - 1s 32ms/step - loss: 0.2302 - val_loss: 0.9645
# Epoch 2/5
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1729 - val_loss: 0.6998
# Epoch 3/5
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1095 - val_loss: 0.3887
# Epoch 4/5
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0471 - val_loss: 0.0622
# Epoch 5/5
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0164 - val_loss: 0.0174
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0162
# Epoch 1/5
# 7/7 [==============================] - 2s 32ms/step - loss: 0.3253 - val_loss: 0.9153
# Epoch 2/5
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2403 - val_loss: 0.6317
# Epoch 3/5
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1382 - val_loss: 0.2727
# Epoch 4/5
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0387 - val_loss: 0.0027
# Epoch 5/5
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0243 - val_loss: 0.0445
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0213
# Epoch 1/5
# 7/7 [==============================] - 1s 32ms/step - loss: 0.2339 - val_loss: 1.0946
# Epoch 2/5
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2349 - val_loss: 1.0943
# Epoch 3/5
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2339 - val_loss: 1.0940
# Epoch 4/5
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2341 - val_loss: 1.0937
# Epoch 5/5
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2348 - val_loss: 1.0934
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3451
# Epoch 1/5
# 7/7 [==============================] - 1s 32ms/step - loss: 0.3477 - val_loss: 1.1034
# Epoch 2/5
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3488 - val_loss: 1.1031
# Epoch 3/5
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3479 - val_loss: 1.1028
# Epoch 4/5
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3481 - val_loss: 1.1026
# Epoch 5/5
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3478 - val_loss: 1.1023
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2328
# Epoch 1/10
# 7/7 [==============================] - 1s 32ms/step - loss: 0.1944 - val_loss: 0.7705
# Epoch 2/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1248 - val_loss: 0.4170
# Epoch 3/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0479 - val_loss: 0.0337
# Epoch 4/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0157 - val_loss: 0.0746
# Epoch 5/10
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0192 - val_loss: 0.0097
# Epoch 6/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0130 - val_loss: 0.0355
# Epoch 7/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 0.0041
# Epoch 8/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0113 - val_loss: 0.0082
# Epoch 9/10
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0103 - val_loss: 0.0052
# Epoch 10/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0090 - val_loss: 0.0037
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0097
# Epoch 1/10
# 7/7 [==============================] - 1s 32ms/step - loss: 0.3447 - val_loss: 0.9647
# Epoch 2/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2579 - val_loss: 0.6960
# Epoch 3/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1556 - val_loss: 0.3451
# Epoch 4/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0521 - val_loss: 0.0159
# Epoch 5/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0163 - val_loss: 0.0416
# Epoch 6/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0205 - val_loss: 0.0153
# Epoch 7/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0126 - val_loss: 0.0521
# Epoch 8/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0146 - val_loss: 0.0298
# Epoch 9/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0111 - val_loss: 0.0034
# Epoch 10/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0127 - val_loss: 0.0062
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 1/10
# 7/7 [==============================] - 1s 31ms/step - loss: 0.2469 - val_loss: 1.1751
# Epoch 2/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2472 - val_loss: 1.1747
# Epoch 3/10
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2464 - val_loss: 1.1742
# Epoch 4/10
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2461 - val_loss: 1.1737
# Epoch 5/10
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2457 - val_loss: 1.1733
# Epoch 6/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2452 - val_loss: 1.1728
# Epoch 7/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2454 - val_loss: 1.1723
# Epoch 8/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2444 - val_loss: 1.1719
# Epoch 9/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2454 - val_loss: 1.1715
# Epoch 10/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2458 - val_loss: 1.1710
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3634
# Epoch 1/10
# 7/7 [==============================] - 1s 34ms/step - loss: 0.3504 - val_loss: 1.1276
# Epoch 2/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3503 - val_loss: 1.1273
# Epoch 3/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3510 - val_loss: 1.1271
# Epoch 4/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3510 - val_loss: 1.1269
# Epoch 5/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3504 - val_loss: 1.1266
# Epoch 6/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3506 - val_loss: 1.1264
# Epoch 7/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3504 - val_loss: 1.1262
# Epoch 8/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3499 - val_loss: 1.1260
# Epoch 9/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3501 - val_loss: 1.1257
# Epoch 10/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3493 - val_loss: 1.1255
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2366
# Epoch 1/20
# 7/7 [==============================] - 2s 33ms/step - loss: 0.2271 - val_loss: 0.9012
# Epoch 2/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1555 - val_loss: 0.5830
# Epoch 3/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0852 - val_loss: 0.2311
# Epoch 4/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0261 - val_loss: 0.0037
# Epoch 5/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0169 - val_loss: 0.0310
# Epoch 6/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0148 - val_loss: 0.0099
# Epoch 7/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0120 - val_loss: 0.0315
# Epoch 8/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0132 - val_loss: 0.0102
# Epoch 9/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: 0.0030
# Epoch 10/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0087 - val_loss: 0.0049
# Epoch 11/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0086 - val_loss: 0.0050
# Epoch 12/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0092 - val_loss: 0.0152
# Epoch 13/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0077 - val_loss: 0.0113
# Epoch 14/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0086 - val_loss: 0.0202
# Epoch 15/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0099 - val_loss: 0.0043
# Epoch 16/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0089 - val_loss: 0.0151
# Epoch 17/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0087 - val_loss: 0.0372
# Epoch 18/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0090 - val_loss: 0.0124
# Epoch 19/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0072 - val_loss: 0.0146
# Epoch 20/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0088 - val_loss: 0.0231
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 1/20
# 7/7 [==============================] - 1s 34ms/step - loss: 0.3141 - val_loss: 0.8007
# Epoch 2/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1916 - val_loss: 0.3884
# Epoch 3/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0675 - val_loss: 0.0222
# Epoch 4/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0144 - val_loss: 0.0469
# Epoch 5/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0196 - val_loss: 0.0077
# Epoch 6/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0124 - val_loss: 0.0428
# Epoch 7/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0119
# Epoch 8/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0098 - val_loss: 0.0062
# Epoch 9/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0094 - val_loss: 0.0048
# Epoch 10/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0091 - val_loss: 0.0065
# Epoch 11/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0096 - val_loss: 0.0109
# Epoch 12/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0108 - val_loss: 0.0103
# Epoch 13/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0091 - val_loss: 0.0035
# Epoch 14/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0100 - val_loss: 0.0049
# Epoch 15/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: 0.0088
# Epoch 16/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0110 - val_loss: 0.0051
# Epoch 17/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0088 - val_loss: 0.0061
# Epoch 18/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0084 - val_loss: 0.0122
# Epoch 19/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0118 - val_loss: 0.0024
# Epoch 20/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0109 - val_loss: 0.0032
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0097
# Epoch 1/20
# 7/7 [==============================] - 1s 35ms/step - loss: 0.2686 - val_loss: 1.2736
# Epoch 2/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2691 - val_loss: 1.2732
# Epoch 3/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2692 - val_loss: 1.2728
# Epoch 4/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2681 - val_loss: 1.2723
# Epoch 5/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2683 - val_loss: 1.2719
# Epoch 6/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2684 - val_loss: 1.2715
# Epoch 7/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2682 - val_loss: 1.2710
# Epoch 8/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2675 - val_loss: 1.2707
# Epoch 9/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2685 - val_loss: 1.2703
# Epoch 10/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2688 - val_loss: 1.2699
# Epoch 11/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2682 - val_loss: 1.2694
# Epoch 12/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2673 - val_loss: 1.2690
# Epoch 13/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2681 - val_loss: 1.2685
# Epoch 14/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2666 - val_loss: 1.2681
# Epoch 15/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2667 - val_loss: 1.2677
# Epoch 16/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2674 - val_loss: 1.2672
# Epoch 17/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2669 - val_loss: 1.2668
# Epoch 18/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2665 - val_loss: 1.2664
# Epoch 19/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2661 - val_loss: 1.2660
# Epoch 20/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2676 - val_loss: 1.2655
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3938
# Epoch 1/20
# 7/7 [==============================] - 1s 32ms/step - loss: 0.2902 - val_loss: 0.9234
# Epoch 2/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2888 - val_loss: 0.9229
# Epoch 3/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2885 - val_loss: 0.9224
# Epoch 4/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2884 - val_loss: 0.9219
# Epoch 5/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2882 - val_loss: 0.9213
# Epoch 6/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2868 - val_loss: 0.9208
# Epoch 7/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2874 - val_loss: 0.9203
# Epoch 8/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2878 - val_loss: 0.9198
# Epoch 9/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2875 - val_loss: 0.9192
# Epoch 10/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2857 - val_loss: 0.9187
# Epoch 11/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2880 - val_loss: 0.9181
# Epoch 12/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2872 - val_loss: 0.9176
# Epoch 13/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2872 - val_loss: 0.9170
# Epoch 14/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2859 - val_loss: 0.9165
# Epoch 15/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2872 - val_loss: 0.9159
# Epoch 16/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2857 - val_loss: 0.9154
# Epoch 17/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2856 - val_loss: 0.9148
# Epoch 18/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2853 - val_loss: 0.9141
# Epoch 19/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2850 - val_loss: 0.9135
# Epoch 20/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2854 - val_loss: 0.9129
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1923
# Epoch 1/5
# 4/4 [==============================] - 2s 61ms/step - loss: 0.2152 - val_loss: 0.9242
# Epoch 2/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1802 - val_loss: 0.7800
# Epoch 3/5
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1429 - val_loss: 0.6152
# Epoch 4/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1031 - val_loss: 0.4253
# Epoch 5/5
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0621 - val_loss: 0.2194
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0545
# Epoch 1/5
# 4/4 [==============================] - 1s 62ms/step - loss: 0.3430 - val_loss: 0.9781
# Epoch 2/5
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2900 - val_loss: 0.8125
# Epoch 3/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2336 - val_loss: 0.6291
# Epoch 4/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1721 - val_loss: 0.4204
# Epoch 5/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1053 - val_loss: 0.1935
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0421
# Epoch 1/5
# 4/4 [==============================] - 1s 62ms/step - loss: 0.2275 - val_loss: 1.0864
# Epoch 2/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2280 - val_loss: 1.0863
# Epoch 3/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2288 - val_loss: 1.0861
# Epoch 4/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2276 - val_loss: 1.0860
# Epoch 5/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2285 - val_loss: 1.0857
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3403
# Epoch 1/5
# 4/4 [==============================] - 1s 61ms/step - loss: 0.3604 - val_loss: 1.1364
# Epoch 2/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3597 - val_loss: 1.1362
# Epoch 3/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3617 - val_loss: 1.1360
# Epoch 4/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3607 - val_loss: 1.1358
# Epoch 5/5
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3597 - val_loss: 1.1356
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2396
# Epoch 1/10
# 4/4 [==============================] - 1s 61ms/step - loss: 0.2268 - val_loss: 0.9671
# Epoch 2/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1881 - val_loss: 0.8330
# Epoch 3/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1535 - val_loss: 0.6880
# Epoch 4/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1186 - val_loss: 0.5209
# Epoch 5/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0811 - val_loss: 0.3218
# Epoch 6/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0426 - val_loss: 0.1231
# Epoch 7/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0178 - val_loss: 0.0065
# Epoch 8/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0170 - val_loss: 0.0129
# Epoch 9/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0198 - val_loss: 0.0021
# Epoch 10/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0143 - val_loss: 0.0139
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 1/10
# 4/4 [==============================] - 1s 61ms/step - loss: 0.3603 - val_loss: 1.0726
# Epoch 2/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3201 - val_loss: 0.9743
# Epoch 3/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2855 - val_loss: 0.8756
# Epoch 4/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2481 - val_loss: 0.7682
# Epoch 5/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2084 - val_loss: 0.6389
# Epoch 6/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1625 - val_loss: 0.4764
# Epoch 7/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1087 - val_loss: 0.2797
# Epoch 8/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0553 - val_loss: 0.0801
# Epoch 9/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0160 - val_loss: 0.0068
# Epoch 10/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0224 - val_loss: 0.0748
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0384
# Epoch 1/10
# 4/4 [==============================] - 1s 63ms/step - loss: 0.2343 - val_loss: 1.1077
# Epoch 2/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2334 - val_loss: 1.1076
# Epoch 3/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2341 - val_loss: 1.1075
# Epoch 4/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2340 - val_loss: 1.1073
# Epoch 5/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2341 - val_loss: 1.1072
# Epoch 6/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2342 - val_loss: 1.1071
# Epoch 7/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2339 - val_loss: 1.1069
# Epoch 8/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2342 - val_loss: 1.1067
# Epoch 9/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2339 - val_loss: 1.1066
# Epoch 10/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2329 - val_loss: 1.1064
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3442
# Epoch 1/10
# 4/4 [==============================] - 1s 61ms/step - loss: 0.3653 - val_loss: 1.1556
# Epoch 2/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3644 - val_loss: 1.1555
# Epoch 3/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3647 - val_loss: 1.1554
# Epoch 4/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3647 - val_loss: 1.1552
# Epoch 5/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3650 - val_loss: 1.1551
# Epoch 6/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3646 - val_loss: 1.1549
# Epoch 7/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3647 - val_loss: 1.1548
# Epoch 8/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3645 - val_loss: 1.1546
# Epoch 9/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3643 - val_loss: 1.1545
# Epoch 10/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3642 - val_loss: 1.1544
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2432
# Epoch 1/20
# 4/4 [==============================] - 1s 62ms/step - loss: 0.1971 - val_loss: 0.7822
# Epoch 2/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1496 - val_loss: 0.5562
# Epoch 3/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0978 - val_loss: 0.3100
# Epoch 4/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0511 - val_loss: 0.0815
# Epoch 5/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0144 - val_loss: 0.0097
# Epoch 6/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0174 - val_loss: 0.0573
# Epoch 7/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0183 - val_loss: 0.0074
# Epoch 8/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0099 - val_loss: 0.0114
# Epoch 9/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0097 - val_loss: 0.0283
# Epoch 10/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0115 - val_loss: 0.0251
# Epoch 11/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0104 - val_loss: 0.0094
# Epoch 12/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0086 - val_loss: 0.0023
# Epoch 13/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0101 - val_loss: 0.0044
# Epoch 14/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0088 - val_loss: 0.0025
# Epoch 15/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0058
# Epoch 16/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0083 - val_loss: 0.0046
# Epoch 17/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0077 - val_loss: 0.0027
# Epoch 18/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0085 - val_loss: 0.0057
# Epoch 19/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0075 - val_loss: 0.0108
# Epoch 20/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0090 - val_loss: 0.0074
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0091
# Epoch 1/20
# 4/4 [==============================] - 1s 61ms/step - loss: 0.3677 - val_loss: 1.0647
# Epoch 2/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3126 - val_loss: 0.9050
# Epoch 3/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2563 - val_loss: 0.7263
# Epoch 4/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1948 - val_loss: 0.5282
# Epoch 5/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1322 - val_loss: 0.3057
# Epoch 6/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0698 - val_loss: 0.0918
# Epoch 7/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0216 - val_loss: 0.0075
# Epoch 8/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0186 - val_loss: 0.0955
# Epoch 9/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0289 - val_loss: 0.0243
# Epoch 10/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0157 - val_loss: 0.0056
# Epoch 11/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0103 - val_loss: 0.0240
# Epoch 12/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0121 - val_loss: 0.0214
# Epoch 13/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0118 - val_loss: 0.0115
# Epoch 14/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0105 - val_loss: 0.0028
# Epoch 15/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0114 - val_loss: 0.0061
# Epoch 16/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0137 - val_loss: 0.0066
# Epoch 17/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0134 - val_loss: 0.0035
# Epoch 18/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0089 - val_loss: 0.0178
# Epoch 19/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0123 - val_loss: 0.0267
# Epoch 20/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0137 - val_loss: 0.0181
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0112
# Epoch 1/20
# 4/4 [==============================] - 1s 61ms/step - loss: 0.2524 - val_loss: 1.1926
# Epoch 2/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2500 - val_loss: 1.1924
# Epoch 3/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2505 - val_loss: 1.1922
# Epoch 4/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2500 - val_loss: 1.1920
# Epoch 5/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2504 - val_loss: 1.1918
# Epoch 6/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2502 - val_loss: 1.1916
# Epoch 7/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2495 - val_loss: 1.1913
# Epoch 8/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2497 - val_loss: 1.1911
# Epoch 9/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2508 - val_loss: 1.1909
# Epoch 10/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2501 - val_loss: 1.1907
# Epoch 11/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2513 - val_loss: 1.1904
# Epoch 12/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2485 - val_loss: 1.1902
# Epoch 13/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2503 - val_loss: 1.1900
# Epoch 14/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2497 - val_loss: 1.1899
# Epoch 15/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2504 - val_loss: 1.1897
# Epoch 16/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2500 - val_loss: 1.1895
# Epoch 17/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2506 - val_loss: 1.1893
# Epoch 18/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2497 - val_loss: 1.1890
# Epoch 19/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2511 - val_loss: 1.1889
# Epoch 20/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2494 - val_loss: 1.1886
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3720
# Epoch 1/20
# 4/4 [==============================] - 1s 62ms/step - loss: 0.3240 - val_loss: 1.0475
# Epoch 2/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3229 - val_loss: 1.0473
# Epoch 3/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3238 - val_loss: 1.0471
# Epoch 4/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3231 - val_loss: 1.0469
# Epoch 5/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3238 - val_loss: 1.0467
# Epoch 6/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3228 - val_loss: 1.0464
# Epoch 7/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3227 - val_loss: 1.0462
# Epoch 8/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3227 - val_loss: 1.0460
# Epoch 9/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3219 - val_loss: 1.0458
# Epoch 10/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3240 - val_loss: 1.0456
# Epoch 11/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3230 - val_loss: 1.0454
# Epoch 12/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3235 - val_loss: 1.0451
# Epoch 13/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3231 - val_loss: 1.0450
# Epoch 14/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3228 - val_loss: 1.0448
# Epoch 15/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3226 - val_loss: 1.0446
# Epoch 16/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3218 - val_loss: 1.0444
# Epoch 17/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3215 - val_loss: 1.0441
# Epoch 18/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3224 - val_loss: 1.0439
# Epoch 19/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3219 - val_loss: 1.0437
# Epoch 20/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3222 - val_loss: 1.0435
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2189
# Epoch 1/20
# 25/25 [==============================] - 1s 10ms/step - loss: 0.1278 - val_loss: 0.0140
# Epoch 2/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0175 - val_loss: 0.0107
# Epoch 3/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.0033
# Epoch 4/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.0027
# Epoch 5/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0091 - val_loss: 0.0026
# Epoch 6/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0085 - val_loss: 0.0025
# Epoch 7/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0081 - val_loss: 0.0039
# Epoch 8/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0023
# Epoch 9/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0076 - val_loss: 0.0026
# Epoch 10/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0048
# Epoch 11/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.0019
# Epoch 12/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 13/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0018
# Epoch 14/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 0.0015
# Epoch 15/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 0.0066
# Epoch 16/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.0078
# Epoch 17/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0018
# Epoch 18/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0021
# Epoch 19/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0035
# Epoch 20/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0048

# %%
grid_search.best_params_
# Out:
# {'batch_size': 8, 'epochs': 20, 'optimizer': 'adam'}

# %%
import matplotlib.pyplot as plt

# Execute grid search
# grid_search.fit(trainX, trainY)

# Extract best hyperparameters from the grid search
best_params = grid_search.best_params_

# Train model using the best hyperparameters
best_model = build_model(optimizer=best_params['optimizer'])
history = best_model.fit(trainX, trainY, epochs=best_params['epochs'], batch_size=best_params['batch_size'], validation_data=(testX, testY), verbose=1, shuffle=False)

# Plot training & validation loss values
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 5))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/20
# 25/25 [==============================] - 1s 11ms/step - loss: 0.1976 - val_loss: 0.2775
# Epoch 2/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0314 - val_loss: 0.0037
# Epoch 3/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0107 - val_loss: 0.0048
# Epoch 4/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0129 - val_loss: 0.0081
# Epoch 5/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0118 - val_loss: 0.0059
# Epoch 6/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0110 - val_loss: 0.0037
# Epoch 7/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0125 - val_loss: 0.0076
# Epoch 8/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0130 - val_loss: 0.0085
# Epoch 9/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0129 - val_loss: 0.0070
# Epoch 10/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0123 - val_loss: 0.0084
# Epoch 11/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0106 - val_loss: 0.0058
# Epoch 12/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0107 - val_loss: 0.0100
# Epoch 13/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0118 - val_loss: 0.0065
# Epoch 14/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0114 - val_loss: 0.0107
# Epoch 15/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0104 - val_loss: 0.0076
# Epoch 16/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0101 - val_loss: 0.0092
# Epoch 17/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0098 - val_loss: 0.0074
# Epoch 18/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0092 - val_loss: 0.0119
# Epoch 19/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0098 - val_loss: 0.0094
# Epoch 20/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0094 - val_loss: 0.0098

# %%
import numpy as np
from skopt import gp_minimize
from skopt.space import Real, Integer
from skopt.utils import use_named_args
from tensorflow.keras.optimizers import Adam


# 定义超参数空间
space  = [Integer(10, 50, name='lstm_neurons'),
          Real(0.2, 0.9, name='dropout_rate'),
          Real(1e-4, 1e-2, name='learning_rate', prior='log-uniform')]

# 定义优化目标函数
@use_named_args(space)
def objective(**params):
    # 在这里构建您的 LSTM 模型
    model = Sequential()
    model.add(LSTM(params['lstm_neurons'], input_shape=(trainX.shape[1], trainX.shape[2])))
    model.add(Dropout(params['dropout_rate']))
    model.add(Dense(1))
    
    optimizer = Adam(learning_rate=params['learning_rate'])
    model.compile(optimizer=optimizer, loss='mse')
    
    history = model.fit(trainX, trainY, epochs=20, batch_size=8, validation_data=(testX, testY), verbose=0, shuffle=False)
    
    # 返回验证损失
    return history.history['val_loss'][-1]

# 执行贝叶斯优化
res = gp_minimize(objective, space, n_calls=50, random_state=0)

# 输出最佳参数
print("Best parameters: {}".format(res.x))
# Out:
# Best parameters: [42, 0.2, 0.0004780881960145376]

# %%
best_lstm_neurons = res.x[0]
best_dropout_rate = res.x[1]
best_learning_rate = res.x[2]

model = Sequential()
model.add(LSTM(units=best_lstm_neurons, return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2]), activation='relu'))
model.add(Dropout(best_dropout_rate))
model.add(LSTM(units=best_lstm_neurons, activation='relu'))
# model.add(Dropout(0.2))
model.add(Dense(1))

optimizer = Adam(learning_rate=best_learning_rate)
model.compile(optimizer=optimizer, loss='mse')

history = model.fit(trainX, trainY, epochs=20, batch_size=8, validation_data=(testX, testY), verbose=1, shuffle=False)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 1s 10ms/step - loss: 0.2379 - val_loss: 0.6322
# Epoch 2/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0779 - val_loss: 0.0617
# Epoch 3/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0151 - val_loss: 0.0035
# Epoch 4/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0126 - val_loss: 0.0238
# Epoch 5/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0123 - val_loss: 0.0080
# Epoch 6/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0105 - val_loss: 0.0090
# Epoch 7/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0104 - val_loss: 0.0044
# Epoch 8/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0102 - val_loss: 0.0049
# Epoch 9/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0101 - val_loss: 0.0037
# Epoch 10/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0103 - val_loss: 0.0036
# Epoch 11/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0100 - val_loss: 0.0040
# Epoch 12/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0105 - val_loss: 0.0031
# Epoch 13/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0092 - val_loss: 0.0029
# Epoch 14/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0092 - val_loss: 0.0027
# Epoch 15/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0106 - val_loss: 0.0027
# Epoch 16/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0030
# Epoch 17/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0101 - val_loss: 0.0026
# Epoch 18/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0089 - val_loss: 0.0032
# Epoch 19/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0091 - val_loss: 0.0035
# Epoch 20/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0088 - val_loss: 0.0025

# %%
import matplotlib.pyplot as plt

# Extract training and validation loss from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot training & validation loss values
plt.figure(figsize=(5, 4))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
prediction = model.predict(testX)
print("prediction\n", prediction)
print("\nPrediction Shape-",prediction.shape)
# Out:
# 2/2 [==============================] - 0s 1ms/step
# prediction
#  [[0.8052903 ]
#  [0.7939794 ]
#  [0.7908851 ]
#  [0.80425245]
#  [0.82281107]
#  [0.8411091 ]
#  [0.865909  ]
#  [0.8649274 ]
#  [0.8734679 ]
#  [0.88824016]
#  [0.9034715 ]
#  [0.92445815]
#  [0.96476734]
#  [0.96559834]
#  [0.962938  ]
#  [0.9633054 ]
#  [0.95743   ]
#  [0.9577222 ]
#  [0.97077423]
#  [0.978568  ]
#  [0.98096853]
#  [0.98337847]
#  [0.9779132 ]
#  [0.9689155 ]
#  [0.9803009 ]
#  [1.0051861 ]
#  [1.0412573 ]
#  [1.0812451 ]
#  [1.1158673 ]
#  [1.1230322 ]
#  [1.1316557 ]
#  [1.1367755 ]
#  [1.1387056 ]
#  [1.1410354 ]
#  [1.16383   ]
#  [1.1862009 ]
#  [1.2200832 ]
#  [1.2414219 ]
#  [1.2581751 ]
#  [1.2643853 ]
#  [1.2774031 ]
#  [1.2823837 ]
#  [1.2854892 ]
#  [1.2942532 ]
#  [1.3209645 ]
#  [1.3438957 ]]
#
# Prediction Shape- (46, 1)

# %%
prediction_copies = np.repeat(prediction, 3, axis=-1)
inverse_transformed_datas = scaler.inverse_transform(prediction_copies)
# pred=scaler.inverse_transform(prediction_copies)

# %%
pred=scaler.inverse_transform(prediction_copies)

# %%
original_copies_array = np.repeat(testY, 3, axis=-1)

original_copies_array.shape

original = scaler.inverse_transform(np.reshape(original_copies_array,(len(testY),3)))

# %%
pred
# Out:
# array([[166.72995, 163.58896, 164.99544],
#        [166.18271, 163.0353 , 164.45143],
#        [166.03302, 162.88382, 164.30263],
#        [166.67973, 163.53815, 164.94553],
#        [167.57759, 164.4466 , 165.8381 ],
#        [168.46286, 165.34229, 166.71814],
#        [169.66267, 166.55623, 167.91089],
#        [169.61519, 166.5082 , 167.8637 ],
#        [170.02837, 166.92625, 168.27443],
#        [170.74306, 167.64935, 168.98491],
#        [171.47995, 168.39493, 169.71747],
#        [172.49529, 169.42221, 170.72682],
#        [174.44543, 171.39536, 172.66548],
#        [174.48564, 171.43604, 172.70544],
#        [174.35693, 171.30582, 172.5775 ],
#        [174.37471, 171.32379, 172.59517],
#        [174.09045, 171.0362 , 172.31259],
#        [174.10458, 171.05049, 172.32664],
#        [174.73605, 171.68939, 172.95439],
#        [175.11311, 172.0709 , 173.32922],
#        [175.22926, 172.1884 , 173.44469],
#        [175.34586, 172.30637, 173.5606 ],
#        [175.08144, 172.03885, 173.29774],
#        [174.64613, 171.5984 , 172.86499],
#        [175.19695, 172.15573, 173.41257],
#        [176.4009 , 173.37386, 174.60942],
#        [178.14603, 175.13953, 176.34427],
#        [180.08063, 177.09694, 178.26749],
#        [181.75566, 178.79169, 179.93263],
#        [182.1023 , 179.14241, 180.27724],
#        [182.51949, 179.56454, 180.69197],
#        [182.76718, 179.81516, 180.93822],
#        [182.86058, 179.90962, 181.03105],
#        [182.9733 , 180.02368, 181.1431 ],
#        [184.07608, 181.13948, 182.2394 ],
#        [185.15839, 182.23453, 183.31532],
#        [186.79762, 183.89307, 184.9449 ],
#        [187.82999, 184.9376 , 185.97119],
#        [188.6405 , 185.75768, 186.77693],
#        [188.94096, 186.06165, 187.07562],
#        [189.57076, 186.69888, 187.7017 ],
#        [189.8117 , 186.94267, 187.94124],
#        [189.96196, 187.09468, 188.0906 ],
#        [190.38597, 187.52368, 188.51212],
#        [191.67825, 188.83119, 189.79678],
#        [192.78766, 189.95369, 190.89966]], dtype=float32)

# %%
pred_High = pred[:, 0]
pred_Low = pred[:, 1]
pred_Mid = pred[:, 2]

# Adjusting the date_range to match the length of pred_High, pred_Low, and pred_Mid
df_test_dropped = df_test.iloc[5:]
date = df_test_dropped.index.tolist()

# Combining the adjusted data
pred_data = pd.DataFrame({
    'Date': date,
    'pred_High': pred_High,
    'pred_Low': pred_Low,
    'pred_Mid': pred_Mid
})

pred_data.head()
# Out:
#         Date   pred_High    pred_Low    pred_Mid
# 0 2023-04-26  166.729950  163.588959  164.995438
# 1 2023-04-27  166.182709  163.035294  164.451431
# 2 2023-04-28  166.033020  162.883820  164.302628
# 3 2023-05-01  166.679733  163.538147  164.945526
# 4 2023-05-02  167.577591  164.446594  165.838104

# %%
original
# Out:
# array([[165.279999  , 162.12193267, 163.55403827],
#        [168.559998  , 165.44057573, 166.81471551],
#        [169.850006  , 166.74578225, 168.09712435],
#        [170.449997  , 167.35284218, 168.69358094],
#        [170.350006  , 167.25167311, 168.59417896],
#        [170.919998  , 167.82838061, 169.16081326],
#        [167.039993  , 163.90266244, 165.30366453],
#        [174.300003  , 171.24820791, 172.52090739],
#        [173.850006  , 170.79290917, 172.07356123],
#        [173.539993  , 170.47924368, 171.76537445],
#        [174.029999  , 170.97502279, 172.25249393],
#        [174.589996  , 171.54161753, 172.80919211],
#        [174.059998  , 171.00537523, 172.28231621],
#        [173.210007  , 170.14536987, 171.43733232],
#        [173.139999  , 170.07453706, 171.36773672],
#        [172.929993  , 169.86205682, 171.15896782],
#        [175.240005  , 172.19928476, 173.45537205],
#        [176.389999  , 173.36282767, 174.59859168],
#        [174.710007  , 171.66304246, 172.92849615],
#        [173.380005  , 170.31737074, 171.6063289 ],
#        [172.419998  , 169.3460532 , 170.65197709],
#        [173.899994  , 170.84348611, 172.12325476],
#        [175.770004  , 172.73552806, 173.98224894],
#        [178.990005  , 175.99346624, 177.18328162],
#        [179.350006  , 176.35770867, 177.54116193],
#        [180.119995  , 177.13676947, 178.30661509],
#        [181.779999  , 178.81633119, 179.95684037],
#        [184.949997  , 182.02367725, 183.1081646 ],
#        [180.119995  , 177.13676947, 178.30661509],
#        [181.210007  , 178.2396237 , 179.39020607],
#        [180.839996  , 177.86525333, 179.02237472],
#        [182.229996  , 179.27162993, 180.40418654],
#        [183.889999  , 180.95119064, 182.05441082],
#        [184.149994  , 181.21424883, 182.31287425],
#        [184.389999  , 181.4570815 , 182.55146543],
#        [186.520004  , 183.61218164, 184.66892304],
#        [186.990005  , 184.08772007, 185.13615536],
#        [186.100006  , 183.18723534, 184.25139915],
#        [185.410004  , 182.48910393, 183.5654618 ],
#        [187.050003  , 184.14842495, 185.19579993],
#        [187.559998  , 184.66442857, 185.70279066],
#        [188.050003  , 185.16020668, 186.18990914],
#        [188.389999  , 185.50420842, 186.5279023 ],
#        [189.899994  , 187.03199377, 188.02900225],
#        [190.070007  , 187.20400982, 188.19801374],
#        [194.479996  , 191.66595611, 192.58202446]])

# %%
original_High = original[:, 0]
original_Low = original[:, 1]
original_Mid = original[:, 2]

# Adjusting the date_range to match the length of pred_High, pred_Low, and pred_Mid
df_test_dropped = df_test.iloc[5:]
date = df_test_dropped.index.tolist()

# Combining the adjusted data
original_data = pd.DataFrame({
    'Date': date,
    'original_High': original_High,
    'original_Low': original_Low,
    'original_Mid': original_Mid
})

original_data.head()
# Out:
#         Date  original_High  original_Low  original_Mid
# 0 2023-04-26     165.279999    162.121933    163.554038
# 1 2023-04-27     168.559998    165.440576    166.814716
# 2 2023-04-28     169.850006    166.745782    168.097124
# 3 2023-05-01     170.449997    167.352842    168.693581
# 4 2023-05-02     170.350006    167.251673    168.594179

# %%
merged_data = pd.merge(pred_data, original_data, on='Date')
merged_data.head()
# Out:
#         Date   pred_High    pred_Low    pred_Mid  original_High  original_Low  \
# 0 2023-04-26  166.729950  163.588959  164.995438     165.279999    162.121933
# 1 2023-04-27  166.182709  163.035294  164.451431     168.559998    165.440576
# 2 2023-04-28  166.033020  162.883820  164.302628     169.850006    166.745782
# 3 2023-05-01  166.679733  163.538147  164.945526     170.449997    167.352842
# 4 2023-05-02  167.577591  164.446594  165.838104     170.350006    167.251673
#
#    original_Mid
# 0    163.554038
# 1    166.814716
# 2    168.097124
# 3    168.693581
# 4    168.594179

# %%
# Calculating MSE, MAE and RMSE for Low_price, High_price and Mid_price

def calculate_metrics(pred, original):
    mse = np.mean((np.array(pred) - np.array(original))**2)
    mae = np.mean(np.abs(np.array(pred) - np.array(original)))
    rmse = np.sqrt(mse)
    return mse, mae, rmse

low_metrics = calculate_metrics(pred_Low, original_Low)
high_metrics = calculate_metrics(pred_High, original_High)
mid_metrics = calculate_metrics(pred_Mid, original_Mid)

low_metrics, high_metrics, mid_metrics
# Out:
# ((5.962952302822289, 2.093856552191961, 2.441915703463633),
#  (5.824889543481759, 2.0694754971340017, 2.4134807940983825),
#  (5.756463049628695, 2.057284245621091, 2.399263022185916))

# %%
df_dates = df.index[-len(original):]

# %%
plt.plot(df_dates, original, color = 'red', label = 'Real Stock Price')
plt.plot(df_dates, pred, color = 'blue', label = 'Predicted  Stock Price')
plt.title(' Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel(' Stock Price')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting the data
plt.figure(figsize=(14, 7))
plt.plot(df_dates, pred_High, label='Predicted High', color='red')
plt.plot(df_dates, pred_Low, label='Predicted Low', color='blue')
plt.plot(df_dates, pred_Mid, label='Predicted Mid', color='green')
plt.title('Predicted High, Low, and Mid Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
def trade_strategy(forecast, real, initial_capital):
    capital = initial_capital
    shares = 0
    buy_dates = []
    sell_dates = []

    for i in range(len(forecast) - 1):
        date = forecast.index[i]
        current_price = real[date]
        next_price = forecast.iloc[i + 1]

        if next_price > current_price and shares == 0:
            shares = capital // current_price
            capital -= shares * current_price
            buy_dates.append(date)

        elif next_price < current_price and shares > 0:
            capital += shares * current_price
            shares = 0
            sell_dates.append(date)

    if shares > 0:
        capital += shares * real.iloc[-1]
        sell_dates.append(forecast.index[-1])

    return capital, buy_dates, sell_dates


pred_price = pred_data.set_index('Date')['pred_Mid']
original_price = original_data.set_index('Date')['original_Mid']


# Creating pandas Series for pred_Mid and original_Mid
# forecast_price = pd.Series(pred_Mid, index=date_range, name='forecast_midpoint')
# real_price = pd.Series(original_Mid, index=date_range, name='real_midpoint')

# Execute the trading strategy again
capital_after_trade, buy_dates, sell_dates = trade_strategy(pred_price, original_price, 100000)

print(f"After implementing the trading strategy, the total capital stands at: ${capital_after_trade:.2f}")
print(f"We buy stocks on these dates: {buy_dates}")
print(f"We sell stocks on these dates: {sell_dates}")
# Out:
# After implementing the trading strategy, the total capital stands at: $116116.21
# We buy stocks on these dates: [Timestamp('2023-04-26 00:00:00'), Timestamp('2023-05-04 00:00:00'), Timestamp('2023-05-12 00:00:00'), Timestamp('2023-05-22 00:00:00'), Timestamp('2023-06-06 00:00:00'), Timestamp('2023-06-14 00:00:00')]
# We sell stocks on these dates: [Timestamp('2023-04-27 00:00:00'), Timestamp('2023-05-05 00:00:00'), Timestamp('2023-05-18 00:00:00'), Timestamp('2023-05-26 00:00:00'), Timestamp('2023-06-12 00:00:00'), Timestamp('2023-06-30 00:00:00')]

# %%
# Filter the original_price to only have dates that are in pred_price
filtered_original_prices = original_price[original_price.index.isin(pred_price.index)]

# Filter buy and sell dates based on the dates in pred_price
filtered_buy_dates = [date for date in buy_dates if date in pred_price.index]
filtered_sell_dates = [date for date in sell_dates if date in pred_price.index]
filtered_dates = filtered_original_prices.index

plt.figure(figsize=(12,6))
plt.plot(filtered_dates, filtered_original_prices, label="Actual Midpoint", color="blue", alpha=0.6)

# Highlight the buy and sell points
plt.scatter(filtered_buy_dates, filtered_original_prices.loc[filtered_buy_dates], color="green", label="Buy", marker="^", alpha=1)
plt.scatter(filtered_sell_dates, filtered_original_prices.loc[filtered_sell_dates], color="red", label="Sell", marker="v", alpha=1)

# Annotate the buy and sell points
for buy_date in filtered_buy_dates:
    price = filtered_original_prices.loc[buy_date]
    plt.annotate(f"Buy @ {price:.2f}", (buy_date, price), textcoords="offset points", xytext=(0,10), ha='center')
for sell_date in filtered_sell_dates:
    price = filtered_original_prices.loc[sell_date]
    plt.annotate(f"Sell @ {price:.2f}", (sell_date, price), textcoords="offset points", xytext=(0,-15), ha='center')

plt.title("Trading Strategy Based on Original Midpoint and Predicted Data")
plt.xlabel("Date")
plt.ylabel("Midpoint Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
merged_data['original_Low'] = merged_data['original_Low'].shift(-1)
merged_data['original_High'] = merged_data['original_High'].shift(-1)
merged_data['original_Mid'] = merged_data['original_Mid'].shift(-1)

def generate_signal(row):
    if row['pred_High'] <= row['original_Mid']:
        return 'Sell'
    elif row['pred_Low'] >= row['original_Mid']:
        return 'Buy'
    else:
        return 'Hold'

merged_data['Signal'] = merged_data.apply(generate_signal, axis=1)
merged_data[['Date', 'pred_Low', 'pred_High', 'original_Low', 'original_High', 'original_Mid', 'Signal']].head(10)
# Out:
#         Date    pred_Low   pred_High  original_Low  original_High  \
# 0 2023-04-26  163.588959  166.729950    165.440576     168.559998
# 1 2023-04-27  163.035294  166.182709    166.745782     169.850006
# 2 2023-04-28  162.883820  166.033020    167.352842     170.449997
# 3 2023-05-01  163.538147  166.679733    167.251673     170.350006
# 4 2023-05-02  164.446594  167.577591    167.828381     170.919998
# 5 2023-05-03  165.342285  168.462860    163.902662     167.039993
# 6 2023-05-04  166.556229  169.662674    171.248208     174.300003
# 7 2023-05-05  166.508194  169.615189    170.792909     173.850006
# 8 2023-05-08  166.926254  170.028366    170.479244     173.539993
# 9 2023-05-09  167.649353  170.743057    170.975023     174.029999
#
#    original_Mid Signal
# 0    166.814716   Sell
# 1    168.097124   Sell
# 2    168.693581   Sell
# 3    168.594179   Sell
# 4    169.160813   Sell
# 5    165.303665    Buy
# 6    172.520907   Sell
# 7    172.073561   Sell
# 8    171.765374   Sell
# 9    172.252494   Sell

# %%
initial_balance = 100000
balance = initial_balance
stock_quantity = 0

# iloc[:-1] is used to avoid NaN in the last row due to the shift operation earlier
for _, row in merged_data.iloc[:-1].iterrows():
    if row['Signal'] == 'Buy' and balance > 0:
        stock_quantity = balance / row['original_Mid']
        balance = 0
    elif row['Signal'] == 'Sell' and stock_quantity > 0:
        balance = stock_quantity * row['original_Mid']
        stock_quantity = 0

# balance + value of stocks held, iloc[-2] means use the penultimate day's data (as the last row might contain NaN due to the shift operation)
final_wealth = balance + stock_quantity * merged_data['original_Mid'].iloc[-2]
print(f"After implementing the above trading strategy, the total capital stands at: ${final_wealth}")
# Out:
# After implementing the above trading strategy, the total capital stands at: $118815.10258592584

# %%
# Identify buy and sell dates
buy_dates = merged_data[merged_data['Signal'] == 'Buy']['Date']
sell_dates = merged_data[merged_data['Signal'] == 'Sell']['Date']
dates = merged_data['Date']

plt.figure(figsize=(12, 7))

# Forecasted price interval
plt.fill_between(dates, merged_data['pred_Low'], merged_data['pred_High'], color='blue', alpha=0.5, label='Forecast Interval')

# Actual price interval
plt.fill_between(dates, merged_data['original_Low'], merged_data['original_High'], color='red', alpha=0.3, label='Actual Interval')

# Buy and sell signals (assuming you have a 'midpoint' column for plotting the signal, if not you might want to use 'original_Mid' or similar)
plt.scatter(buy_dates, merged_data[merged_data['Signal'] == 'Buy']['original_Mid'], color='green', marker='^', label='Buy Signal')
plt.scatter(sell_dates, merged_data[merged_data['Signal'] == 'Sell']['original_Mid'], color='black', marker='v', label='Sell Signal')

plt.title('Forecast vs Actual Price Intervals with Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.tight_layout()
plt.show()
