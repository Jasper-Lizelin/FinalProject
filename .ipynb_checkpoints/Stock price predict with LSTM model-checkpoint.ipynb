# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

# %%
df=pd.read_csv("AAPL.csv",parse_dates=["Date"],index_col=[0])
print(df.index.freq)
missing_dates = pd.date_range(start=df.index.min(), end=df.index.max()).difference(df.index)
print(missing_dates)
df.shape
# Out:
# None
# DatetimeIndex(['2022-07-02', '2022-07-03', '2022-07-04', '2022-07-09',
#                '2022-07-10', '2022-07-16', '2022-07-17', '2022-07-23',
#                '2022-07-24', '2022-07-30',
#                ...
#                '2023-05-29', '2023-06-03', '2023-06-04', '2023-06-10',
#                '2023-06-11', '2023-06-17', '2023-06-18', '2023-06-19',
#                '2023-06-24', '2023-06-25'],
#               dtype='datetime64[ns]', length=114, freq=None)
# (251, 6)

# %%
# Dropping the specified columns
df.drop(columns=["Open", "Close", "Adj Close", "Volume"], inplace=True)

# Calculate the midpoint of low and high and save it as 'Mid'
df["Mid"] = (df["Low"] + df["High"]) / 2
df.to_csv('apple.csv')
df.head()
# Out:
#                   High         Low         Mid
# Date
# 2022-07-01  139.039993  135.660004  137.349998
# 2022-07-05  141.610001  136.929993  139.269997
# 2022-07-06  144.119995  141.080002  142.599998
# 2022-07-07  146.550003  143.279999  144.915001
# 2022-07-08  147.550003  145.000000  146.275002

# %%
def train_test_split(data, prediction_size):
    train_size = int(len(data) * (1-prediction_size))
    train = pd.DataFrame(data[0:train_size])
    test = pd.DataFrame(data[train_size:len(data)])
    return train, test
df_train, df_test = train_test_split(df, 0.2)

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (200, 3)
# (51, 3)

# %%
# 归一化
scaler = MinMaxScaler(feature_range=(0,1))
df_train_scaled = scaler.fit_transform(df_train)
df_test_scaled = scaler.transform(df_test)

# %%
len(df_test_scaled)
# Out:
# 51

# %%
def generate_time_series_data(input_data, history_length):
    X_data, Y_data = [], []

    for idx in range(history_length, len(input_data)):
        X_data.append(input_data[idx-history_length :idx, 0:input_data.shape[1]])
#         Y_data.append(input_data[idx, 0:input_data.shape[1]]) #这是沿第二个维度（特征）的切片，从第一个特征开始，到最后一个特征结束。简而言之，我们选择了所有的特征。
        Y_data.append(input_data[idx, 0])
    return np.array(X_data), np.array(Y_data)

# %%
df_train.shape[1]
# Out:
# 3

# %%
trainX,trainY=generate_time_series_data(df_train_scaled,5)
testX,testY=generate_time_series_data(df_test_scaled,5)
print("trainX Shape-- ",trainX.shape) #trainX consists of 1984 time Windows, each consisting of 30 consecutive time steps with 6 features per time step
print("trainY Shape-- ",trainY.shape)
print("testX Shape-- ",testX.shape)
print("testY Shape-- ",testY.shape)
print("trainX[0]-- \n",trainX[0])
print("\ntrainY[0]-- ",trainY[0])
# Out:
# trainX Shape--  (195, 5, 3)
# trainY Shape--  (195,)
# testX Shape--  (46, 5, 3)
# testY Shape--  (46,)
# trainX[0]--
#  [[0.23294743 0.23472945 0.23048131]
#  [0.28606872 0.26067407 0.27040227]
#  [0.33794955 0.34545465 0.33964027]
#  [0.38817708 0.39039841 0.38777422]
#  [0.40884678 0.42553633 0.4160516 ]]
#
# trainY[0]--  0.390037270982055

# %%
def build_model(optimizer):
    grid_model = Sequential()
    grid_model.add(LSTM(50,return_sequences=True,input_shape=(5,3), activation='relu'))
    grid_model.add(Dropout(0.2))
    grid_model.add(LSTM(units=50, activation='relu'))
#     grid_model.add(Dropout(0.2))
    grid_model.add(Dense(units=1))

    grid_model.compile(loss = 'mse',optimizer = optimizer)
    return grid_model

grid_model = KerasRegressor(build_fn=build_model,verbose=1,validation_data=(testX,testY))
parameters = {'batch_size' : [16, 32, 64], # , 128, 256, 512
              'epochs' : [5, 10, 20], # , 200
              'optimizer' : ['adam','Adadelta'] }

grid_search  = GridSearchCV(estimator = grid_model,
                            param_grid = parameters,
                            cv = 2)
# Out:
# C:\Users\eq220\AppData\Local\Temp\ipykernel_24988\2182992767.py:12: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   grid_model = KerasRegressor(build_fn=build_model,verbose=1,validation_data=(testX,testY))

# %%
grid_search = grid_search.fit(trainX,trainY)
# Out:
# Epoch 1/5
# 7/7 [==============================] - 1s 36ms/step - loss: 0.2125 - val_loss: 0.8860
# Epoch 2/5
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1525 - val_loss: 0.5982
# Epoch 3/5
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0846 - val_loss: 0.2205
# Epoch 4/5
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0223 - val_loss: 0.0182
# Epoch 5/5
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0273 - val_loss: 0.0114
# 7/7 [==============================] - 0s 0s/step - loss: 0.0140
# Epoch 1/5
# 7/7 [==============================] - 1s 33ms/step - loss: 0.3230 - val_loss: 0.8868
# Epoch 2/5
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2320 - val_loss: 0.6194
# Epoch 3/5
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1383 - val_loss: 0.2827
# Epoch 4/5
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0386 - val_loss: 0.0032
# Epoch 5/5
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0204 - val_loss: 0.0435
# 7/7 [==============================] - 0s 0s/step - loss: 0.0232
# Epoch 1/5
# 7/7 [==============================] - 1s 31ms/step - loss: 0.2325 - val_loss: 1.1013
# Epoch 2/5
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2336 - val_loss: 1.1011
# Epoch 3/5
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2333 - val_loss: 1.1009
# Epoch 4/5
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2326 - val_loss: 1.1007
# Epoch 5/5
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2329 - val_loss: 1.1005
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3444
# Epoch 1/5
# 7/7 [==============================] - 1s 31ms/step - loss: 0.3171 - val_loss: 1.0195
# Epoch 2/5
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3165 - val_loss: 1.0192
# Epoch 3/5
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3172 - val_loss: 1.0189
# Epoch 4/5
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3182 - val_loss: 1.0186
# Epoch 5/5
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3161 - val_loss: 1.0183
# 7/7 [==============================] - 0s 0s/step - loss: 0.2164
# Epoch 1/10
# 7/7 [==============================] - 1s 31ms/step - loss: 0.2006 - val_loss: 0.8010
# Epoch 2/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1403 - val_loss: 0.5165
# Epoch 3/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0741 - val_loss: 0.1472
# Epoch 4/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0170 - val_loss: 0.0400
# Epoch 5/10
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0241 - val_loss: 0.0131
# Epoch 6/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0128 - val_loss: 0.0417
# Epoch 7/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0149 - val_loss: 0.0312
# Epoch 8/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0110 - val_loss: 0.0038
# Epoch 9/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0106 - val_loss: 0.0111
# Epoch 10/10
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0100 - val_loss: 0.0044
# 7/7 [==============================] - 0s 0s/step - loss: 0.0087
# Epoch 1/10
# 7/7 [==============================] - 1s 58ms/step - loss: 0.2944 - val_loss: 0.8232
# Epoch 2/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2116 - val_loss: 0.5689
# Epoch 3/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1178 - val_loss: 0.2286
# Epoch 4/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0308 - val_loss: 0.0022
# Epoch 5/10
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0207 - val_loss: 0.0110
# Epoch 6/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0165 - val_loss: 0.0243
# Epoch 7/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0131 - val_loss: 0.0462
# Epoch 8/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0123 - val_loss: 0.0130
# Epoch 9/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0126 - val_loss: 0.0034
# Epoch 10/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0091 - val_loss: 0.0131
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0128
# Epoch 1/10
# 7/7 [==============================] - 1s 36ms/step - loss: 0.2310 - val_loss: 1.0936
# Epoch 2/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2313 - val_loss: 1.0934
# Epoch 3/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2303 - val_loss: 1.0932
# Epoch 4/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2316 - val_loss: 1.0929
# Epoch 5/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2310 - val_loss: 1.0927
# Epoch 6/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2305 - val_loss: 1.0925
# Epoch 7/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2307 - val_loss: 1.0922
# Epoch 8/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2310 - val_loss: 1.0920
# Epoch 9/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2305 - val_loss: 1.0917
# Epoch 10/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2308 - val_loss: 1.0915
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3432
# Epoch 1/10
# 7/7 [==============================] - 1s 32ms/step - loss: 0.3476 - val_loss: 1.1058
# Epoch 2/10
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3470 - val_loss: 1.1056
# Epoch 3/10
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3468 - val_loss: 1.1052
# Epoch 4/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3473 - val_loss: 1.1049
# Epoch 5/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3464 - val_loss: 1.1046
# Epoch 6/10
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3458 - val_loss: 1.1043
# Epoch 7/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3452 - val_loss: 1.1040
# Epoch 8/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3471 - val_loss: 1.1037
# Epoch 9/10
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3456 - val_loss: 1.1034
# Epoch 10/10
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3449 - val_loss: 1.1031
# 7/7 [==============================] - 0s 0s/step - loss: 0.2317
# Epoch 1/20
# 7/7 [==============================] - 1s 31ms/step - loss: 0.1949 - val_loss: 0.7537
# Epoch 2/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1253 - val_loss: 0.3856
# Epoch 3/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0470 - val_loss: 0.0263
# Epoch 4/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0146 - val_loss: 0.0741
# Epoch 5/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0169 - val_loss: 0.0032
# Epoch 6/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0107 - val_loss: 0.0285
# Epoch 7/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0118 - val_loss: 0.0165
# Epoch 8/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0093 - val_loss: 0.0031
# Epoch 9/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0040
# Epoch 10/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0078 - val_loss: 0.0105
# Epoch 11/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0081 - val_loss: 0.0292
# Epoch 12/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0076 - val_loss: 0.0225
# Epoch 13/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.0136
# Epoch 14/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 0.0214
# Epoch 15/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 0.0645
# Epoch 16/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0082 - val_loss: 0.0107
# Epoch 17/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0250
# Epoch 18/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.0219
# Epoch 19/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0069 - val_loss: 0.0100
# Epoch 20/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 0.0182
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0094
# Epoch 1/20
# 7/7 [==============================] - 2s 33ms/step - loss: 0.2974 - val_loss: 0.8057
# Epoch 2/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2028 - val_loss: 0.4886
# Epoch 3/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0942 - val_loss: 0.1052
# Epoch 4/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0204 - val_loss: 0.0456
# Epoch 5/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0253 - val_loss: 0.0022
# Epoch 6/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0132 - val_loss: 0.0561
# Epoch 7/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0163 - val_loss: 0.0352
# Epoch 8/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0112 - val_loss: 0.0040
# Epoch 9/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0114 - val_loss: 0.0031
# Epoch 10/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0108 - val_loss: 0.0137
# Epoch 11/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0107 - val_loss: 0.0140
# Epoch 12/20
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0106 - val_loss: 0.0100
# Epoch 13/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0101 - val_loss: 0.0064
# Epoch 14/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0100 - val_loss: 0.0030
# Epoch 15/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0094 - val_loss: 0.0063
# Epoch 16/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0104 - val_loss: 0.0127
# Epoch 17/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0093 - val_loss: 0.0063
# Epoch 18/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0108 - val_loss: 0.0030
# Epoch 19/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0087 - val_loss: 0.0070
# Epoch 20/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: 0.0052
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0102
# Epoch 1/20
# 7/7 [==============================] - 1s 31ms/step - loss: 0.2413 - val_loss: 1.1459
# Epoch 2/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2419 - val_loss: 1.1457
# Epoch 3/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2420 - val_loss: 1.1454
# Epoch 4/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2422 - val_loss: 1.1451
# Epoch 5/20
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2415 - val_loss: 1.1448
# Epoch 6/20
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2409 - val_loss: 1.1446
# Epoch 7/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2420 - val_loss: 1.1443
# Epoch 8/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2406 - val_loss: 1.1440
# Epoch 9/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2410 - val_loss: 1.1437
# Epoch 10/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2414 - val_loss: 1.1435
# Epoch 11/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2411 - val_loss: 1.1432
# Epoch 12/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2409 - val_loss: 1.1429
# Epoch 13/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2404 - val_loss: 1.1427
# Epoch 14/20
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2409 - val_loss: 1.1424
# Epoch 15/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2413 - val_loss: 1.1422
# Epoch 16/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2407 - val_loss: 1.1419
# Epoch 17/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2409 - val_loss: 1.1416
# Epoch 18/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2408 - val_loss: 1.1414
# Epoch 19/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2404 - val_loss: 1.1411
# Epoch 20/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2407 - val_loss: 1.1408
# 7/7 [==============================] - 0s 0s/step - loss: 0.3564
# Epoch 1/20
# 7/7 [==============================] - 1s 31ms/step - loss: 0.3491 - val_loss: 1.1264
# Epoch 2/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3494 - val_loss: 1.1260
# Epoch 3/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3488 - val_loss: 1.1256
# Epoch 4/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3485 - val_loss: 1.1251
# Epoch 5/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3494 - val_loss: 1.1247
# Epoch 6/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3484 - val_loss: 1.1243
# Epoch 7/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3495 - val_loss: 1.1239
# Epoch 8/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3474 - val_loss: 1.1235
# Epoch 9/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3476 - val_loss: 1.1230
# Epoch 10/20
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3476 - val_loss: 1.1226
# Epoch 11/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3479 - val_loss: 1.1221
# Epoch 12/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3467 - val_loss: 1.1217
# Epoch 13/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3470 - val_loss: 1.1212
# Epoch 14/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3473 - val_loss: 1.1208
# Epoch 15/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3476 - val_loss: 1.1204
# Epoch 16/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3463 - val_loss: 1.1199
# Epoch 17/20
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3476 - val_loss: 1.1195
# Epoch 18/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3472 - val_loss: 1.1190
# Epoch 19/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3462 - val_loss: 1.1186
# Epoch 20/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3476 - val_loss: 1.1181
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2348
# Epoch 1/5
# 4/4 [==============================] - 1s 58ms/step - loss: 0.2426 - val_loss: 1.0323
# Epoch 2/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1984 - val_loss: 0.8449
# Epoch 3/5
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1539 - val_loss: 0.6352
# Epoch 4/5
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1055 - val_loss: 0.4068
# Epoch 5/5
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0611 - val_loss: 0.1829
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0478
# Epoch 1/5
# 4/4 [==============================] - 1s 63ms/step - loss: 0.3784 - val_loss: 1.1038
# Epoch 2/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3311 - val_loss: 0.9963
# Epoch 3/5
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2929 - val_loss: 0.9005
# Epoch 4/5
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2566 - val_loss: 0.7922
# Epoch 5/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2120 - val_loss: 0.6522
# 4/4 [==============================] - 0s 0s/step - loss: 0.1169
# Epoch 1/5
# 4/4 [==============================] - 1s 58ms/step - loss: 0.2429 - val_loss: 1.1598
# Epoch 2/5
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2440 - val_loss: 1.1595
# Epoch 3/5
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2446 - val_loss: 1.1593
# Epoch 4/5
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2422 - val_loss: 1.1591
# Epoch 5/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2432 - val_loss: 1.1588
# 4/4 [==============================] - 0s 0s/step - loss: 0.3608
# Epoch 1/5
# 4/4 [==============================] - 1s 56ms/step - loss: 0.3497 - val_loss: 1.1216
# Epoch 2/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3493 - val_loss: 1.1214
# Epoch 3/5
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3477 - val_loss: 1.1212
# Epoch 4/5
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3490 - val_loss: 1.1210
# Epoch 5/5
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3489 - val_loss: 1.1209
# 4/4 [==============================] - 0s 0s/step - loss: 0.2363
# Epoch 1/10
# 4/4 [==============================] - 1s 63ms/step - loss: 0.2268 - val_loss: 0.9331
# Epoch 2/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1797 - val_loss: 0.7425
# Epoch 3/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1375 - val_loss: 0.5531
# Epoch 4/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0945 - val_loss: 0.3407
# Epoch 5/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0528 - val_loss: 0.1315
# Epoch 6/10
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0187 - val_loss: 0.0066
# Epoch 7/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0103 - val_loss: 0.0432
# Epoch 8/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0224 - val_loss: 0.0491
# Epoch 9/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0180 - val_loss: 0.0069
# Epoch 10/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0108 - val_loss: 0.0102
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0097
# Epoch 1/10
# 4/4 [==============================] - 1s 63ms/step - loss: 0.3242 - val_loss: 0.9308
# Epoch 2/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2622 - val_loss: 0.7510
# Epoch 3/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2009 - val_loss: 0.5368
# Epoch 4/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1322 - val_loss: 0.3104
# Epoch 5/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0652 - val_loss: 0.0948
# Epoch 6/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0167 - val_loss: 0.0028
# Epoch 7/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0188 - val_loss: 0.0476
# Epoch 8/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0355 - val_loss: 0.0104
# Epoch 9/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0182 - val_loss: 0.0144
# Epoch 10/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0118 - val_loss: 0.0464
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0138
# Epoch 1/10
# 4/4 [==============================] - 1s 62ms/step - loss: 0.2342 - val_loss: 1.1095
# Epoch 2/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2345 - val_loss: 1.1093
# Epoch 3/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2352 - val_loss: 1.1091
# Epoch 4/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2342 - val_loss: 1.1089
# Epoch 5/10
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2337 - val_loss: 1.1088
# Epoch 6/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2341 - val_loss: 1.1086
# Epoch 7/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2343 - val_loss: 1.1084
# Epoch 8/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2337 - val_loss: 1.1082
# Epoch 9/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2334 - val_loss: 1.1081
# Epoch 10/10
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2348 - val_loss: 1.1078
# 4/4 [==============================] - 0s 0s/step - loss: 0.3461
# Epoch 1/10
# 4/4 [==============================] - 1s 63ms/step - loss: 0.3863 - val_loss: 1.2350
# Epoch 2/10
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3854 - val_loss: 1.2348
# Epoch 3/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3859 - val_loss: 1.2346
# Epoch 4/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3863 - val_loss: 1.2344
# Epoch 5/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3855 - val_loss: 1.2342
# Epoch 6/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3843 - val_loss: 1.2339
# Epoch 7/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3853 - val_loss: 1.2337
# Epoch 8/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3840 - val_loss: 1.2335
# Epoch 9/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3867 - val_loss: 1.2333
# Epoch 10/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3847 - val_loss: 1.2331
# 4/4 [==============================] - 0s 0s/step - loss: 0.2593
# Epoch 1/20
# 4/4 [==============================] - 1s 64ms/step - loss: 0.2017 - val_loss: 0.8523
# Epoch 2/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1643 - val_loss: 0.7004
# Epoch 3/20
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1283 - val_loss: 0.5366
# Epoch 4/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0897 - val_loss: 0.3454
# Epoch 5/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0527 - val_loss: 0.1490
# Epoch 6/20
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0213 - val_loss: 0.0162
# Epoch 7/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0110 - val_loss: 0.0197
# Epoch 8/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0195 - val_loss: 0.0193
# Epoch 9/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0149 - val_loss: 0.0027
# Epoch 10/20
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0101 - val_loss: 0.0156
# Epoch 11/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0108 - val_loss: 0.0221
# Epoch 12/20
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0098 - val_loss: 0.0301
# Epoch 13/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0124 - val_loss: 0.0253
# Epoch 14/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0106 - val_loss: 0.0132
# Epoch 15/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0088 - val_loss: 0.0036
# Epoch 16/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0085 - val_loss: 0.0035
# Epoch 17/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0086 - val_loss: 0.0040
# Epoch 18/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0080 - val_loss: 0.0031
# Epoch 19/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0075 - val_loss: 0.0058
# Epoch 20/20
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 0.0102
# 4/4 [==============================] - 0s 0s/step - loss: 0.0097
# Epoch 1/20
# 4/4 [==============================] - 1s 58ms/step - loss: 0.3312 - val_loss: 0.9601
# Epoch 2/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2821 - val_loss: 0.8302
# Epoch 3/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2355 - val_loss: 0.6811
# Epoch 4/20
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1822 - val_loss: 0.5081
# Epoch 5/20
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1262 - val_loss: 0.3009
# Epoch 6/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0643 - val_loss: 0.0925
# Epoch 7/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0186 - val_loss: 0.0038
# Epoch 8/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0160 - val_loss: 0.0422
# Epoch 9/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0246 - val_loss: 0.0220
# Epoch 10/20
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0162 - val_loss: 0.0023
# Epoch 11/20
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0112 - val_loss: 0.0206
# Epoch 12/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0120 - val_loss: 0.0340
# Epoch 13/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0120 - val_loss: 0.0268
# Epoch 14/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0122 - val_loss: 0.0135
# Epoch 15/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0103 - val_loss: 0.0088
# Epoch 16/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0103 - val_loss: 0.0097
# Epoch 17/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 18/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0089 - val_loss: 0.0065
# Epoch 19/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0101 - val_loss: 0.0057
# Epoch 20/20
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0085
# 4/4 [==============================] - 0s 0s/step - loss: 0.0109
# Epoch 1/20
# 4/4 [==============================] - 1s 57ms/step - loss: 0.2447 - val_loss: 1.1590
# Epoch 2/20
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2447 - val_loss: 1.1588
# Epoch 3/20
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2445 - val_loss: 1.1586
# Epoch 4/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2444 - val_loss: 1.1583
# Epoch 5/20
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2448 - val_loss: 1.1581
# Epoch 6/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2450 - val_loss: 1.1580
# Epoch 7/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2453 - val_loss: 1.1578
# Epoch 8/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2441 - val_loss: 1.1576
# Epoch 9/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2447 - val_loss: 1.1573
# Epoch 10/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2447 - val_loss: 1.1571
# Epoch 11/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2451 - val_loss: 1.1570
# Epoch 12/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2448 - val_loss: 1.1567
# Epoch 13/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2446 - val_loss: 1.1566
# Epoch 14/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2442 - val_loss: 1.1564
# Epoch 15/20
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2443 - val_loss: 1.1562
# Epoch 16/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2440 - val_loss: 1.1560
# Epoch 17/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2448 - val_loss: 1.1558
# Epoch 18/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2443 - val_loss: 1.1556
# Epoch 19/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2436 - val_loss: 1.1555
# Epoch 20/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2443 - val_loss: 1.1553
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3629
# Epoch 1/20
# 4/4 [==============================] - 1s 59ms/step - loss: 0.3716 - val_loss: 1.1968
# Epoch 2/20
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3721 - val_loss: 1.1966
# Epoch 3/20
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3714 - val_loss: 1.1964
# Epoch 4/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3703 - val_loss: 1.1962
# Epoch 5/20
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3708 - val_loss: 1.1960
# Epoch 6/20
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3704 - val_loss: 1.1958
# Epoch 7/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3710 - val_loss: 1.1956
# Epoch 8/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3710 - val_loss: 1.1955
# Epoch 9/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3703 - val_loss: 1.1953
# Epoch 10/20
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3713 - val_loss: 1.1951
# Epoch 11/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3705 - val_loss: 1.1949
# Epoch 12/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3694 - val_loss: 1.1947
# Epoch 13/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3690 - val_loss: 1.1945
# Epoch 14/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3697 - val_loss: 1.1943
# Epoch 15/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3708 - val_loss: 1.1941
# Epoch 16/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3686 - val_loss: 1.1939
# Epoch 17/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3702 - val_loss: 1.1937
# Epoch 18/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3699 - val_loss: 1.1936
# Epoch 19/20
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3706 - val_loss: 1.1934
# Epoch 20/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3702 - val_loss: 1.1932
# 4/4 [==============================] - 0s 0s/step - loss: 0.2507
# Epoch 1/5
# 2/2 [==============================] - 1s 184ms/step - loss: 0.2329 - val_loss: 1.0302
# Epoch 2/5
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2153 - val_loss: 0.9667
# Epoch 3/5
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1984 - val_loss: 0.9055
# Epoch 4/5
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1822 - val_loss: 0.8445
# Epoch 5/5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1660 - val_loss: 0.7797
# 2/2 [==============================] - 0s 0s/step - loss: 0.2312
# Epoch 1/5
# 2/2 [==============================] - 1s 163ms/step - loss: 0.3450 - val_loss: 1.0327
# Epoch 2/5
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3165 - val_loss: 0.9548
# Epoch 3/5
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2879 - val_loss: 0.8803
# Epoch 4/5
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2625 - val_loss: 0.8030
# Epoch 5/5
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2327 - val_loss: 0.7168
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1376
# Epoch 1/5
# 2/2 [==============================] - 1s 184ms/step - loss: 0.2431 - val_loss: 1.1534
# Epoch 2/5
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2433 - val_loss: 1.1533
# Epoch 3/5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2430 - val_loss: 1.1532
# Epoch 4/5
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2427 - val_loss: 1.1531
# Epoch 5/5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2434 - val_loss: 1.1530
# 2/2 [==============================] - 0s 0s/step - loss: 0.3601
# Epoch 1/5
# 2/2 [==============================] - 2s 189ms/step - loss: 0.3298 - val_loss: 1.0465
# Epoch 2/5
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3298 - val_loss: 1.0464
# Epoch 3/5
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3297 - val_loss: 1.0463
# Epoch 4/5
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3298 - val_loss: 1.0462
# Epoch 5/5
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3309 - val_loss: 1.0461
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2203
# Epoch 1/10
# 2/2 [==============================] - 1s 173ms/step - loss: 0.1961 - val_loss: 0.8649
# Epoch 2/10
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1779 - val_loss: 0.7877
# Epoch 3/10
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1580 - val_loss: 0.7049
# Epoch 4/10
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1383 - val_loss: 0.6178
# Epoch 5/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1192 - val_loss: 0.5248
# Epoch 6/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0970 - val_loss: 0.4249
# Epoch 7/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0748 - val_loss: 0.3211
# Epoch 8/10
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0557 - val_loss: 0.2171
# Epoch 9/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0379 - val_loss: 0.1196
# Epoch 10/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0230 - val_loss: 0.0420
# 2/2 [==============================] - 0s 0s/step - loss: 0.0157
# Epoch 1/10
# 2/2 [==============================] - 1s 174ms/step - loss: 0.3735 - val_loss: 1.1393
# Epoch 2/10
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3477 - val_loss: 1.0719
# Epoch 3/10
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3230 - val_loss: 1.0070
# Epoch 4/10
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2998 - val_loss: 0.9430
# Epoch 5/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2768 - val_loss: 0.8757
# Epoch 6/10
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2524 - val_loss: 0.8040
# Epoch 7/10
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2268 - val_loss: 0.7281
# Epoch 8/10
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2005 - val_loss: 0.6451
# Epoch 9/10
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1737 - val_loss: 0.5545
# Epoch 10/10
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1425 - val_loss: 0.4556
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0757
# Epoch 1/10
# 2/2 [==============================] - 1s 166ms/step - loss: 0.2297 - val_loss: 1.0766
# Epoch 2/10
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2290 - val_loss: 1.0765
# Epoch 3/10
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2301 - val_loss: 1.0764
# Epoch 4/10
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2285 - val_loss: 1.0763
# Epoch 5/10
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2287 - val_loss: 1.0762
# Epoch 6/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2292 - val_loss: 1.0761
# Epoch 7/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2291 - val_loss: 1.0761
# Epoch 8/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2292 - val_loss: 1.0760
# Epoch 9/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2294 - val_loss: 1.0759
# Epoch 10/10
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2289 - val_loss: 1.0758
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3373
# Epoch 1/10
# 2/2 [==============================] - 1s 174ms/step - loss: 0.3794 - val_loss: 1.2100
# Epoch 2/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3789 - val_loss: 1.2099
# Epoch 3/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3786 - val_loss: 1.2098
# Epoch 4/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3785 - val_loss: 1.2097
# Epoch 5/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3780 - val_loss: 1.2096
# Epoch 6/10
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3784 - val_loss: 1.2095
# Epoch 7/10
# 2/2 [==============================] - 0s 20ms/step - loss: 0.3779 - val_loss: 1.2094
# Epoch 8/10
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3773 - val_loss: 1.2093
# Epoch 9/10
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3773 - val_loss: 1.2092
# Epoch 10/10
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3782 - val_loss: 1.2091
# 2/2 [==============================] - 0s 0s/step - loss: 0.2549
# Epoch 1/20
# 2/2 [==============================] - 1s 173ms/step - loss: 0.2496 - val_loss: 1.1260
# Epoch 2/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2246 - val_loss: 1.0190
# Epoch 3/20
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2025 - val_loss: 0.9115
# Epoch 4/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1767 - val_loss: 0.8098
# Epoch 5/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1558 - val_loss: 0.7122
# Epoch 6/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1364 - val_loss: 0.6145
# Epoch 7/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1137 - val_loss: 0.5146
# Epoch 8/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0956 - val_loss: 0.4129
# Epoch 9/20
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0738 - val_loss: 0.3095
# Epoch 10/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0552 - val_loss: 0.2076
# Epoch 11/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0366 - val_loss: 0.1150
# Epoch 12/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0222 - val_loss: 0.0412
# Epoch 13/20
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0130 - val_loss: 0.0044
# Epoch 14/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0116 - val_loss: 0.0150
# Epoch 15/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0160 - val_loss: 0.0469
# Epoch 16/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0215 - val_loss: 0.0541
# Epoch 17/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0207 - val_loss: 0.0358
# Epoch 18/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0172 - val_loss: 0.0138
# Epoch 19/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0147 - val_loss: 0.0034
# Epoch 20/20
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0116 - val_loss: 0.0051
# 2/2 [==============================] - 0s 0s/step - loss: 0.0087
# Epoch 1/20
# 2/2 [==============================] - 1s 176ms/step - loss: 0.3354 - val_loss: 1.0206
# Epoch 2/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3092 - val_loss: 0.9515
# Epoch 3/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2832 - val_loss: 0.8762
# Epoch 4/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2572 - val_loss: 0.7927
# Epoch 5/20
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2260 - val_loss: 0.7047
# Epoch 6/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1964 - val_loss: 0.6127
# Epoch 7/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1677 - val_loss: 0.5088
# Epoch 8/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1344 - val_loss: 0.3939
# Epoch 9/20
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0953 - val_loss: 0.2721
# Epoch 10/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0662 - val_loss: 0.1511
# Epoch 11/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0300 - val_loss: 0.0516
# Epoch 12/20
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0138 - val_loss: 0.0032
# Epoch 13/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0139 - val_loss: 0.0203
# Epoch 14/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0260 - val_loss: 0.0418
# Epoch 15/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0294 - val_loss: 0.0298
# Epoch 16/20
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0269 - val_loss: 0.0079
# Epoch 17/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0161 - val_loss: 0.0026
# Epoch 18/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0130 - val_loss: 0.0131
# Epoch 19/20
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0103 - val_loss: 0.0291
# Epoch 20/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0122 - val_loss: 0.0421
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0128
# Epoch 1/20
# 2/2 [==============================] - 1s 173ms/step - loss: 0.2551 - val_loss: 1.2019
# Epoch 2/20
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2551 - val_loss: 1.2018
# Epoch 3/20
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2552 - val_loss: 1.2016
# Epoch 4/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2545 - val_loss: 1.2015
# Epoch 5/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2552 - val_loss: 1.2014
# Epoch 6/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2548 - val_loss: 1.2012
# Epoch 7/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2553 - val_loss: 1.2011
# Epoch 8/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2551 - val_loss: 1.2009
# Epoch 9/20
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2550 - val_loss: 1.2008
# Epoch 10/20
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2549 - val_loss: 1.2006
# Epoch 11/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2555 - val_loss: 1.2005
# Epoch 12/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2542 - val_loss: 1.2003
# Epoch 13/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2539 - val_loss: 1.2002
# Epoch 14/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2545 - val_loss: 1.2000
# Epoch 15/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2556 - val_loss: 1.1999
# Epoch 16/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2547 - val_loss: 1.1997
# Epoch 17/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2534 - val_loss: 1.1996
# Epoch 18/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2537 - val_loss: 1.1994
# Epoch 19/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2555 - val_loss: 1.1993
# Epoch 20/20
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2543 - val_loss: 1.1991
# 2/2 [==============================] - 0s 0s/step - loss: 0.3746
# Epoch 1/20
# 2/2 [==============================] - 1s 173ms/step - loss: 0.3695 - val_loss: 1.1739
# Epoch 2/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3680 - val_loss: 1.1738
# Epoch 3/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3695 - val_loss: 1.1737
# Epoch 4/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3679 - val_loss: 1.1736
# Epoch 5/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3688 - val_loss: 1.1735
# Epoch 6/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3688 - val_loss: 1.1734
# Epoch 7/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3680 - val_loss: 1.1733
# Epoch 8/20
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3684 - val_loss: 1.1732
# Epoch 9/20
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3684 - val_loss: 1.1731
# Epoch 10/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3681 - val_loss: 1.1730
# Epoch 11/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3682 - val_loss: 1.1729
# Epoch 12/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3688 - val_loss: 1.1728
# Epoch 13/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3671 - val_loss: 1.1727
# Epoch 14/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3682 - val_loss: 1.1726
# Epoch 15/20
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3675 - val_loss: 1.1725
# Epoch 16/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3678 - val_loss: 1.1724
# Epoch 17/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3684 - val_loss: 1.1723
# Epoch 18/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3680 - val_loss: 1.1722
# Epoch 19/20
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3683 - val_loss: 1.1721
# Epoch 20/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3679 - val_loss: 1.1721
# 2/2 [==============================] - 0s 0s/step - loss: 0.2464
# Epoch 1/20
# 13/13 [==============================] - 1s 17ms/step - loss: 0.2216 - val_loss: 0.5764
# Epoch 2/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0690 - val_loss: 0.0076
# Epoch 3/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0188 - val_loss: 0.0093
# Epoch 4/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0122 - val_loss: 0.0211
# Epoch 5/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0111 - val_loss: 0.0038
# Epoch 6/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0101 - val_loss: 0.0050
# Epoch 7/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.0033
# Epoch 8/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0085 - val_loss: 0.0037
# Epoch 9/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0085 - val_loss: 0.0029
# Epoch 10/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0085
# Epoch 11/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0084 - val_loss: 0.0026
# Epoch 12/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.0028
# Epoch 13/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0084 - val_loss: 0.0033
# Epoch 14/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0084 - val_loss: 0.0027
# Epoch 15/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0081 - val_loss: 0.0024
# Epoch 16/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0082 - val_loss: 0.0034
# Epoch 17/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0031
# Epoch 18/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0077 - val_loss: 0.0023
# Epoch 19/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0021
# Epoch 20/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 0.0033

# %%
grid_search.best_params_
# Out:
# {'batch_size': 16, 'epochs': 20, 'optimizer': 'adam'}

# %%
import matplotlib.pyplot as plt

# Execute grid search
# grid_search.fit(trainX, trainY)

# Extract best hyperparameters from the grid search
best_params = grid_search.best_params_

# Train model using the best hyperparameters
best_model = build_model(optimizer=best_params['optimizer'])
history = best_model.fit(trainX, trainY, epochs=best_params['epochs'], batch_size=best_params['batch_size'], validation_data=(testX, testY), verbose=1, shuffle=False)

# Plot training & validation loss values
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 5))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/20
# 13/13 [==============================] - 1s 18ms/step - loss: 0.2600 - val_loss: 0.8523
# Epoch 2/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1516 - val_loss: 0.4133
# Epoch 3/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0436 - val_loss: 0.0122
# Epoch 4/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0255 - val_loss: 0.0331
# Epoch 5/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0152 - val_loss: 0.0409
# Epoch 6/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0139 - val_loss: 0.0141
# Epoch 7/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0134 - val_loss: 0.0151
# Epoch 8/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0131 - val_loss: 0.0066
# Epoch 9/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0111 - val_loss: 0.0032
# Epoch 10/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0103 - val_loss: 0.0030
# Epoch 11/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0091 - val_loss: 0.0032
# Epoch 12/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0033
# Epoch 13/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0091 - val_loss: 0.0032
# Epoch 14/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0030
# Epoch 15/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0088 - val_loss: 0.0029
# Epoch 16/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0082 - val_loss: 0.0028
# Epoch 17/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0080 - val_loss: 0.0038
# Epoch 18/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0076 - val_loss: 0.0030
# Epoch 19/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0085 - val_loss: 0.0026
# Epoch 20/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0074 - val_loss: 0.0027

# %%
import numpy as np
from skopt import gp_minimize
from skopt.space import Real, Integer
from skopt.utils import use_named_args
from tensorflow.keras.optimizers import Adam


# 定义超参数空间
space  = [Integer(10, 50, name='lstm_neurons'),
          Real(0.2, 0.9, name='dropout_rate'),
          Real(1e-4, 1e-2, name='learning_rate', prior='log-uniform')]

# 定义优化目标函数
@use_named_args(space)
def objective(**params):
    # 在这里构建您的 LSTM 模型
    model = Sequential()
    model.add(LSTM(params['lstm_neurons'], input_shape=(trainX.shape[1], trainX.shape[2])))
    model.add(Dropout(params['dropout_rate']))
    model.add(Dense(1))
    
    optimizer = Adam(learning_rate=params['learning_rate'])
    model.compile(optimizer=optimizer, loss='mse')
    
    history = model.fit(trainX, trainY, epochs=20, batch_size=16, validation_data=(testX, testY), verbose=0, shuffle=False)
    
    # 返回验证损失
    return history.history['val_loss'][-1]

# 执行贝叶斯优化
res = gp_minimize(objective, space, n_calls=50, random_state=0)

# 输出最佳参数
print("Best parameters: {}".format(res.x))
# Out:
# C:\Users\eq220\Application\Anaconda\lib\site-packages\skopt\optimizer\optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Best parameters: [50, 0.2, 0.0030561073466192205]

# %%
best_lstm_neurons = res.x[0]
best_dropout_rate = res.x[1]
best_learning_rate = res.x[2]

model = Sequential()
model.add(LSTM(units=best_lstm_neurons, return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2]), activation='relu'))
model.add(Dropout(best_dropout_rate))
model.add(LSTM(units=best_lstm_neurons, activation='relu'))
# model.add(Dropout(0.2))
model.add(Dense(1))

optimizer = Adam(learning_rate=best_learning_rate)
model.compile(optimizer=optimizer, loss='mse')

history = model.fit(trainX, trainY, epochs=20, batch_size=16, validation_data=(testX, testY), verbose=1, shuffle=False)
# Out:
# Epoch 1/20
# 13/13 [==============================] - 1s 17ms/step - loss: 0.1349 - val_loss: 0.0512
# Epoch 2/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0280 - val_loss: 0.2342
# Epoch 3/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0343 - val_loss: 0.0130
# Epoch 4/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0140 - val_loss: 0.0313
# Epoch 5/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0158 - val_loss: 0.0072
# Epoch 6/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.0033
# Epoch 7/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0114 - val_loss: 0.0053
# Epoch 8/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0100 - val_loss: 0.0040
# Epoch 9/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.0040
# Epoch 10/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0105 - val_loss: 0.0025
# Epoch 11/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0107 - val_loss: 0.0071
# Epoch 12/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0036
# Epoch 13/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0095 - val_loss: 0.0043
# Epoch 14/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0081 - val_loss: 0.0026
# Epoch 15/20
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0095 - val_loss: 0.0066
# Epoch 16/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0091 - val_loss: 0.0053
# Epoch 17/20
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0075 - val_loss: 0.0023
# Epoch 18/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0087 - val_loss: 0.0086
# Epoch 19/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.0084
# Epoch 20/20
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 0.0017

# %%
import matplotlib.pyplot as plt

# Extract training and validation loss from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot training & validation loss values
plt.figure(figsize=(6, 4))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
prediction = model.predict(testX)
print("prediction\n", prediction)
print("\nPrediction Shape-",prediction.shape)
# Out:
# 2/2 [==============================] - 0s 0s/step
# prediction
#  [[0.8112954 ]
#  [0.80310595]
#  [0.80865455]
#  [0.8362188 ]
#  [0.85542166]
#  [0.86739177]
#  [0.8812849 ]
#  [0.8664232 ]
#  [0.8854164 ]
#  [0.91962606]
#  [0.9308807 ]
#  [0.94606787]
#  [0.97247565]
#  [0.970911  ]
#  [0.96363485]
#  [0.9634006 ]
#  [0.9574491 ]
#  [0.9648608 ]
#  [0.9908978 ]
#  [0.99194044]
#  [0.97884053]
#  [0.9675742 ]
#  [0.96817017]
#  [0.97978824]
#  [1.0084013 ]
#  [1.0315837 ]
#  [1.0582516 ]
#  [1.0941379 ]
#  [1.1256284 ]
#  [1.1163572 ]
#  [1.1102918 ]
#  [1.1171471 ]
#  [1.130109  ]
#  [1.1464875 ]
#  [1.1662934 ]
#  [1.1811514 ]
#  [1.2096947 ]
#  [1.2307578 ]
#  [1.2385122 ]
#  [1.2310222 ]
#  [1.2376553 ]
#  [1.2560261 ]
#  [1.2637427 ]
#  [1.2715839 ]
#  [1.296067  ]
#  [1.3183293 ]]
#
# Prediction Shape- (46, 1)

# %%
prediction_copies = np.repeat(prediction, 3, axis=-1)
inverse_transformed_datas = scaler.inverse_transform(prediction_copies)
# pred=scaler.inverse_transform(prediction_copies)

# %%
pred=scaler.inverse_transform(prediction_copies)

# %%
original_copies_array = np.repeat(testY, 3, axis=-1)

original_copies_array.shape

original = scaler.inverse_transform(np.reshape(original_copies_array,(len(testY),3)))

# %%
pred
# Out:
# array([[167.02046, 163.8829 , 165.28426],
#        [166.62427, 163.48203, 164.89038],
#        [166.8927 , 163.75363, 165.15724],
#        [168.22626, 165.1029 , 166.48294],
#        [169.1553 , 166.04288, 167.40651],
#        [169.7344 , 166.62883, 167.98221],
#        [170.40656, 167.3089 , 168.65039],
#        [169.68755, 166.5814 , 167.93562],
#        [170.60645, 167.51112, 168.8491 ],
#        [172.2615 , 169.18568, 170.49442],
#        [172.806  , 169.73662, 171.0357 ],
#        [173.54076, 170.48001, 171.76614],
#        [174.81837, 171.77267, 173.03622],
#        [174.74266, 171.69609, 172.96097],
#        [174.39066, 171.33992, 172.61102],
#        [174.37932, 171.32846, 172.59975],
#        [174.09138, 171.03712, 172.31352],
#        [174.44997, 171.39993, 172.66998],
#        [175.70963, 172.67444, 173.92223],
#        [175.76007, 172.72548, 173.97238],
#        [175.1263 , 172.08424, 173.34233],
#        [174.58124, 171.53275, 172.80049],
#        [174.61006, 171.56192, 172.82915],
#        [175.17215, 172.13063, 173.38791],
#        [176.55644, 173.53123, 174.76407],
#        [177.67801, 174.66602, 175.87901],
#        [178.9682 , 175.97142, 177.1616 ],
#        [180.70438, 177.72804, 178.88756],
#        [182.22789, 179.2695 , 180.4021 ],
#        [181.77936, 178.81567, 179.9562 ],
#        [181.48592, 178.51877, 179.66449],
#        [181.81757, 178.85434, 179.99419],
#        [182.44467, 179.48883, 180.6176 ],
#        [183.23706, 180.29056, 181.4053 ],
#        [184.19527, 181.26006, 182.35788],
#        [184.9141 , 181.98735, 183.07248],
#        [186.29503, 183.38455, 184.44527],
#        [187.31406, 184.41559, 185.4583 ],
#        [187.68921, 184.79517, 185.83124],
#        [187.32686, 184.42853, 185.47102],
#        [187.64775, 184.75322, 185.79004],
#        [188.53654, 185.65247, 186.67358],
#        [188.90987, 186.0302 , 187.04471],
#        [189.28923, 186.41402, 187.42183],
#        [190.47371, 187.61247, 188.59933],
#        [191.55077, 188.70221, 189.67004]], dtype=float32)

# %%
pred_High = pred[:, 0]
pred_Low = pred[:, 1]
pred_Mid = pred[:, 2]

# Adjusting the date_range to match the length of pred_High, pred_Low, and pred_Mid
df_test_dropped = df_test.iloc[5:]
date = df_test_dropped.index.tolist()

# Combining the adjusted data
pred_data = pd.DataFrame({
    'Date': date,
    'pred_High': pred_High,
    'pred_Low': pred_Low,
    'pred_Mid': pred_Mid
})

pred_data.head()
# Out:
#         Date   pred_High    pred_Low    pred_Mid
# 0 2023-04-26  167.020462  163.882904  165.284256
# 1 2023-04-27  166.624268  163.482025  164.890381
# 2 2023-04-28  166.892700  163.753632  165.157242
# 3 2023-05-01  168.226257  165.102905  166.482941
# 4 2023-05-02  169.155304  166.042877  167.406509

# %%
original
# Out:
# array([[165.279999  , 162.12193267, 163.55403827],
#        [168.559998  , 165.44057573, 166.81471551],
#        [169.850006  , 166.74578225, 168.09712435],
#        [170.449997  , 167.35284218, 168.69358094],
#        [170.350006  , 167.25167311, 168.59417896],
#        [170.919998  , 167.82838061, 169.16081326],
#        [167.039993  , 163.90266244, 165.30366453],
#        [174.300003  , 171.24820791, 172.52090739],
#        [173.850006  , 170.79290917, 172.07356123],
#        [173.539993  , 170.47924368, 171.76537445],
#        [174.029999  , 170.97502279, 172.25249393],
#        [174.589996  , 171.54161753, 172.80919211],
#        [174.059998  , 171.00537523, 172.28231621],
#        [173.210007  , 170.14536987, 171.43733232],
#        [173.139999  , 170.07453706, 171.36773672],
#        [172.929993  , 169.86205682, 171.15896782],
#        [175.240005  , 172.19928476, 173.45537205],
#        [176.389999  , 173.36282767, 174.59859168],
#        [174.710007  , 171.66304246, 172.92849615],
#        [173.380005  , 170.31737074, 171.6063289 ],
#        [172.419998  , 169.3460532 , 170.65197709],
#        [173.899994  , 170.84348611, 172.12325476],
#        [175.770004  , 172.73552806, 173.98224894],
#        [178.990005  , 175.99346624, 177.18328162],
#        [179.350006  , 176.35770867, 177.54116193],
#        [180.119995  , 177.13676947, 178.30661509],
#        [181.779999  , 178.81633119, 179.95684037],
#        [184.949997  , 182.02367725, 183.1081646 ],
#        [180.119995  , 177.13676947, 178.30661509],
#        [181.210007  , 178.2396237 , 179.39020607],
#        [180.839996  , 177.86525333, 179.02237472],
#        [182.229996  , 179.27162993, 180.40418654],
#        [183.889999  , 180.95119064, 182.05441082],
#        [184.149994  , 181.21424883, 182.31287425],
#        [184.389999  , 181.4570815 , 182.55146543],
#        [186.520004  , 183.61218164, 184.66892304],
#        [186.990005  , 184.08772007, 185.13615536],
#        [186.100006  , 183.18723534, 184.25139915],
#        [185.410004  , 182.48910393, 183.5654618 ],
#        [187.050003  , 184.14842495, 185.19579993],
#        [187.559998  , 184.66442857, 185.70279066],
#        [188.050003  , 185.16020668, 186.18990914],
#        [188.389999  , 185.50420842, 186.5279023 ],
#        [189.899994  , 187.03199377, 188.02900225],
#        [190.070007  , 187.20400982, 188.19801374],
#        [194.479996  , 191.66595611, 192.58202446]])

# %%
original_High = original[:, 0]
original_Low = original[:, 1]
original_Mid = original[:, 2]

# Adjusting the date_range to match the length of pred_High, pred_Low, and pred_Mid
df_test_dropped = df_test.iloc[5:]
date = df_test_dropped.index.tolist()

# Combining the adjusted data
original_data = pd.DataFrame({
    'Date': date,
    'original_High': original_High,
    'original_Low': original_Low,
    'original_Mid': original_Mid
})

original_data.head()
# Out:
#         Date  original_High  original_Low  original_Mid
# 0 2023-04-26     165.279999    162.121933    163.554038
# 1 2023-04-27     168.559998    165.440576    166.814716
# 2 2023-04-28     169.850006    166.745782    168.097124
# 3 2023-05-01     170.449997    167.352842    168.693581
# 4 2023-05-02     170.350006    167.251673    168.594179

# %%
merged_data = pd.merge(pred_data, original_data, on='Date')
merged_data.head()
# Out:
#         Date   pred_High    pred_Low    pred_Mid  original_High  original_Low  \
# 0 2023-04-26  167.020462  163.882904  165.284256     165.279999    162.121933
# 1 2023-04-27  166.624268  163.482025  164.890381     168.559998    165.440576
# 2 2023-04-28  166.892700  163.753632  165.157242     169.850006    166.745782
# 3 2023-05-01  168.226257  165.102905  166.482941     170.449997    167.352842
# 4 2023-05-02  169.155304  166.042877  167.406509     170.350006    167.251673
#
#    original_Mid
# 0    163.554038
# 1    166.814716
# 2    168.097124
# 3    168.693581
# 4    168.594179

# %%
# Calculating MSE, MAE and RMSE for Low_price, High_price and Mid_price

def calculate_metrics(pred, original):
    mse = np.mean((np.array(pred) - np.array(original))**2)
    mae = np.mean(np.abs(np.array(pred) - np.array(original)))
    rmse = np.sqrt(mse)
    return mse, mae, rmse

low_metrics = calculate_metrics(pred_Low, original_Low)
high_metrics = calculate_metrics(pred_High, original_High)
mid_metrics = calculate_metrics(pred_Mid, original_Mid)

low_metrics, high_metrics, mid_metrics
# Out:
# ((4.0093640199356635, 1.6612345767939087, 2.0023396365091672),
#  (3.9165296366053752, 1.641890077530571, 1.9790223941646985),
#  (3.870523257262049, 1.6322188055695777, 1.9673645461027423))

# %%
df_dates = df.index[-len(original):]

# %%
plt.plot(df_dates, original, color = 'red', label = 'Real Stock Price')
plt.plot(df_dates, pred, color = 'blue', label = 'Predicted  Stock Price')
plt.title(' Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel(' Stock Price')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting the data
plt.figure(figsize=(14, 7))
plt.plot(df_dates, pred_High, label='Predicted High', color='red')
plt.plot(df_dates, pred_Low, label='Predicted Low', color='blue')
plt.plot(df_dates, pred_Mid, label='Predicted Mid', color='green')
plt.title('Predicted High, Low, and Mid Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
def trade_strategy(forecast, real, initial_capital):
    capital = initial_capital
    shares = 0
    buy_dates = []
    sell_dates = []

    for i in range(len(forecast) - 1):
        date = forecast.index[i]
        current_price = real[date]
        next_price = forecast.iloc[i + 1]

        if next_price > current_price and shares == 0:
            shares = capital // current_price
            capital -= shares * current_price
            buy_dates.append(date)

        elif next_price < current_price and shares > 0:
            capital += shares * current_price
            shares = 0
            sell_dates.append(date)

    if shares > 0:
        capital += shares * real.iloc[-1]
        sell_dates.append(forecast.index[-1])

    return capital, buy_dates, sell_dates


pred_price = pred_data.set_index('Date')['pred_Mid']
original_price = original_data.set_index('Date')['original_Mid']


# Creating pandas Series for pred_Mid and original_Mid
# forecast_price = pd.Series(pred_Mid, index=date_range, name='forecast_midpoint')
# real_price = pd.Series(original_Mid, index=date_range, name='real_midpoint')

# Execute the trading strategy again
capital_after_trade, buy_dates, sell_dates = trade_strategy(pred_price, original_price, 100000)

print(f"After implementing the trading strategy, the total capital stands at: ${capital_after_trade:.2f}")
print(f"We buy stocks on these dates: {buy_dates}")
print(f"We sell stocks on these dates: {sell_dates}")
# Out:
# After implementing the trading strategy, the total capital stands at: $115625.34
# We buy stocks on these dates: [Timestamp('2023-04-26 00:00:00'), Timestamp('2023-05-04 00:00:00'), Timestamp('2023-05-11 00:00:00'), Timestamp('2023-05-22 00:00:00'), Timestamp('2023-06-06 00:00:00'), Timestamp('2023-06-13 00:00:00'), Timestamp('2023-06-16 00:00:00')]
# We sell stocks on these dates: [Timestamp('2023-04-27 00:00:00'), Timestamp('2023-05-05 00:00:00'), Timestamp('2023-05-18 00:00:00'), Timestamp('2023-05-26 00:00:00'), Timestamp('2023-06-12 00:00:00'), Timestamp('2023-06-15 00:00:00'), Timestamp('2023-06-30 00:00:00')]

# %%
# Filter the original_price to only have dates that are in pred_price
filtered_original_prices = original_price[original_price.index.isin(pred_price.index)]

# Filter buy and sell dates based on the dates in pred_price
filtered_buy_dates = [date for date in buy_dates if date in pred_price.index]
filtered_sell_dates = [date for date in sell_dates if date in pred_price.index]
filtered_dates = filtered_original_prices.index

plt.figure(figsize=(12,6))
plt.plot(filtered_dates, filtered_original_prices, label="Actual Midpoint", color="blue", alpha=0.6)

# Highlight the buy and sell points
plt.scatter(filtered_buy_dates, filtered_original_prices.loc[filtered_buy_dates], color="green", label="Buy", marker="^", alpha=1)
plt.scatter(filtered_sell_dates, filtered_original_prices.loc[filtered_sell_dates], color="red", label="Sell", marker="v", alpha=1)

# Annotate the buy and sell points
for buy_date in filtered_buy_dates:
    price = filtered_original_prices.loc[buy_date]
    plt.annotate(f"Buy @ {price:.2f}", (buy_date, price), textcoords="offset points", xytext=(0,10), ha='center')
for sell_date in filtered_sell_dates:
    price = filtered_original_prices.loc[sell_date]
    plt.annotate(f"Sell @ {price:.2f}", (sell_date, price), textcoords="offset points", xytext=(0,-15), ha='center')

plt.title("Trading Strategy Based on Original Midpoint and Predicted Data")
plt.xlabel("Date")
plt.ylabel("Midpoint Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
merged_data['original_Low'] = merged_data['original_Low'].shift(-1)
merged_data['original_High'] = merged_data['original_High'].shift(-1)
merged_data['original_Mid'] = merged_data['original_Mid'].shift(-1)

def generate_signal(row):
    if row['pred_High'] <= row['original_Mid']:
        return 'Sell'
    elif row['pred_Low'] >= row['original_Mid']:
        return 'Buy'
    else:
        return 'Hold'

merged_data['Signal'] = merged_data.apply(generate_signal, axis=1)
merged_data[['Date', 'pred_Low', 'pred_High', 'original_Low', 'original_High', 'original_Mid', 'Signal']].head(10)
# Out:
#         Date    pred_Low   pred_High  original_Low  original_High  \
# 0 2023-04-26  163.882904  167.020462    167.251673     170.350006
# 1 2023-04-27  163.482025  166.624268    167.828381     170.919998
# 2 2023-04-28  163.753632  166.892700    163.902662     167.039993
# 3 2023-05-01  165.102905  168.226257    171.248208     174.300003
# 4 2023-05-02  166.042877  169.155304    170.792909     173.850006
# 5 2023-05-03  166.628830  169.734406    170.479244     173.539993
# 6 2023-05-04  167.308899  170.406555    170.975023     174.029999
# 7 2023-05-05  166.581406  169.687546    171.541618     174.589996
# 8 2023-05-08  167.511124  170.606445    171.005375     174.059998
# 9 2023-05-09  169.185684  172.261505    170.145370     173.210007
#
#    original_Mid Signal
# 0    168.594179   Sell
# 1    169.160813   Sell
# 2    165.303665   Hold
# 3    172.520907   Sell
# 4    172.073561   Sell
# 5    171.765374   Sell
# 6    172.252494   Sell
# 7    172.809192   Sell
# 8    172.282316   Sell
# 9    171.437332   Hold

# %%
initial_balance = 100000
balance = initial_balance
stock_quantity = 0

# iloc[:-1] is used to avoid NaN in the last row due to the shift operation earlier
for _, row in merged_data.iloc[:-1].iterrows():
    if row['Signal'] == 'Buy' and balance > 0:
        stock_quantity = balance / row['original_Mid']
        balance = 0
    elif row['Signal'] == 'Sell' and stock_quantity > 0:
        balance = stock_quantity * row['original_Mid']
        stock_quantity = 0

# balance + value of stocks held, iloc[-2] means use the penultimate day's data (as the last row might contain NaN due to the shift operation)
final_wealth = balance + stock_quantity * merged_data['original_Mid'].iloc[-2]
final_wealth
# Out:
# nan

# %%
# Identify buy and sell dates
buy_dates = merged_data[merged_data['Signal'] == 'Buy']['Date']
sell_dates = merged_data[merged_data['Signal'] == 'Sell']['Date']
dates = merged_data['Date']

plt.figure(figsize=(12, 7))

# Forecasted price interval
plt.fill_between(dates, merged_data['pred_Low'], merged_data['pred_High'], color='blue', alpha=0.5, label='Forecast Interval')

# Actual price interval
plt.fill_between(dates, merged_data['original_Low'], merged_data['original_High'], color='red', alpha=0.3, label='Actual Interval')

# Buy and sell signals (assuming you have a 'midpoint' column for plotting the signal, if not you might want to use 'original_Mid' or similar)
plt.scatter(buy_dates, merged_data[merged_data['Signal'] == 'Buy']['original_Mid'], color='green', marker='^', label='Buy Signal')
plt.scatter(sell_dates, merged_data[merged_data['Signal'] == 'Sell']['original_Mid'], color='black', marker='v', label='Sell Signal')

plt.title('Forecast vs Actual Price Intervals with Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.tight_layout()
plt.show()
